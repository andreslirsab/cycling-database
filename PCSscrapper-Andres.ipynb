# %% [markdown]
# # PCS Riders Scrapper

# %% [markdown]
# Importamos librerías necesarias

# %%
# coding: utf8
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import os
import re
import sys
from IPython.display import clear_output

# %% [markdown]
# ### Función principal de scrapping

# %%
user_agent = {'User-agent': 'Mozilla/5.0'}

# Funcion base para obtener el contendio HTML de una URL y parsearlo con BeautifulSoup
def download_soup(url):
    print('Empezando petición a: ' + url)
    response = requests.get(url, headers=user_agent)
    if response.status_code == 200:
        page = response.text
        soup = BeautifulSoup(page, 'lxml')
        print('Petición completada con éxito!')
        return soup
    else:
        print('Error, código de estado: '+ response.status_code)

# %% [markdown]
# ### Obtención de URLs Equipos

# %%
def get_team_urls(year):
    # Creamos el directorio si no existe
    newdir = 'data/team_urls' 
    if not os.path.exists(newdir):
        os.makedirs(newdir)
    
    print("Obteniendo URL de equipos, año {}".format(year))
    url_str = "https://www.procyclingstats.com/teams.php?s=worldtour&year=" + str(year)
    # Obtenemos la lista de equipos
    startlist = download_soup(url_str).find_all('a', href = re.compile('team/'))
    # Obtenemos las URLs de los equipos
    urls = [x['href'] for x in startlist]
    list_team_urls = ["https://www.procyclingstats.com/" + u for u in urls if u[-4:] == str(year) ]
    
    # Guardamos las URLs en un archivo CSV
    df_teams = pd.DataFrame()
    df_teams["team_url"] = list_team_urls
    df_teams = df_teams.drop_duplicates("team_url")
    ouputfile_str = newdir + "/team_urls_" + str(year) + ".csv"
    df_teams.to_csv(ouputfile_str)
        
    print("URLs conseguidas, año {}".format(year))

# %%
# Obtenemos las URLs de los equipos del año indicado (en este caso 2024)
get_team_urls(2024)
# Out:
# Obteniendo URL de equipos, año 2024
# Empezando petición a: https://www.procyclingstats.com/teams.php?s=worldtour&year=2024
# Petición completada con éxito!
# URLs conseguidas, año 2024

# %% [markdown]
# ### Obtención de URL de corredores

# %%
# Función para obtener las URLs de los ciclistas de cada equipo
# Utiliza el archivo creado con get_team_urls
# Descarga cada página de equipo y busca las URLs de los ciclistas
# Crea su propio archivo de URLs de ciclistas

def get_riders_urls(start_year, end_year):
    print("Obteniendo URLs de ciclistas")
    df_rider_urls = pd.DataFrame(columns=["rider_url"])

    # Iteramos sobre los años de los que tenemos URLs de equipos
    for year in range(start_year, end_year+1):
        df_team_urls = pd.read_csv("data/team_urls/team_urls_" + str(year) + ".csv")
        list_rider_urls = []

        # Iteramos sobre los equipos
        for idx, row in df_team_urls.iterrows():
            url = row["team_url"]
            # Corregimos un error en el nombre de un equipo
            if url=="https://www.procyclingstats.com/team/intermarche-circus-want-2024":
                print('Equipo no existente')
            else:
                # Descargamos la página del equipo
                timer = 0.5 + 0.5 * random.random()
                time.sleep(timer)
                riders = download_soup(url).find_all('td')
                riders = riders[:(29*3)]
                ciclistas = []
                for i in range(1, len(riders), 3):
                    ciclistas.append(riders[i].find_all('a'))

                # Expresión regular para encontrar el valor de href
                patron = r'href="(.*?)"'
                # Lista para almacenar los valores de href
                urls = []
                # Iterar sobre cada cadena en la lista
                for cadena in ciclistas:
                    cadena = str(cadena)
                    # Buscar el valor de href en la cadena
                    resultado = re.search(patron, cadena)
                    # Verificar si se encontró el valor y agregarlo a la lista
                    if resultado:
                        valor_href = resultado.group(1)
                        urls.append(valor_href)

                # Añadimos las URLs de los ciclistas a la lista
                for u in urls:
                    list_rider_urls.append('https://www.procyclingstats.com/' + u)
        # Creamos un DataFrame con las URLs de los ciclist
        tmp_rider_urls = pd.DataFrame()
        tmp_rider_urls["rider_url"] = list_rider_urls
        df_rider_urls = pd.concat([df_rider_urls, tmp_rider_urls])
        df_rider_urls = df_rider_urls.drop_duplicates("rider_url")
    # Guardamos el DataFrame en un archivo CSV
    df_rider_urls.to_csv("data/rider_urls.csv")
    print('URLs de ciclistas obtenidas')

# %%
# Obtenemos las URLs de los ciclistas de los equipos de 2024
get_riders_urls(2024,2024)
# Out:
# Obteniendo URLs de ciclistas
# Empezando petición a: https://www.procyclingstats.com/team/alpecin-deceuninck-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/arkea-b-b-hotels-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/ineos-grenadiers-2024
# Petición completada con éxito!
# Equipo no existente
# Empezando petición a: https://www.procyclingstats.com/team/astana-qazaqstan-team-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/bahrain-victorious-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/bora-hansgrohe-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/cofidis-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/decathlon-ag2r-la-mondiale-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/ef-education-easypost-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/groupama-fdj-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/lidl-trek-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/movistar-team-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/soudal-quick-step-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/team-dsm-firmenich-postnl-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/team-jayco-alula-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/team-visma-lease-a-bike-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/uae-team-emirates-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/intermarche-wanty-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/red-bull-bora-hansgrohe-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/bingoal-wb-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/burgos-bh-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/caja-rural-seguros-rga-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/equipo-kern-pharma-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/euskaltel-euskadi-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/israel-premier-tech-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/lotto-dstny-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/q365-pro-cycing-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/tdt-unibet-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/team-corratec-vini-fantini-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/team-flanders-baloise-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/team-novo-nordisk-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/team-polti-kometa-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/totalenergies-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/tudor-pro-cycling-team-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/uno-x-mobility-2024
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/team/vf-group-bardiani-csf-faizane-2024
# Petición completada con éxito!
# Finished get_riders_url

# %% [markdown]
# ### Obtenemos datos de los ciclistas

# %%
# Función para obtener la información de un ciclista
# Utiliza el archivo creado con get_riders_urls
# Descarga cada página de ciclista y extrae la información
# Crea su propio archivo de información de ciclistas

def get_uniquerider_infos(rider_url):
    '''Función para obtener la información de un ciclista'''
    rider_soup = download_soup(rider_url)
    rider_infos = pd.Series()
    
### Nombre completo
    rider_infos["fullname"] = rider_soup.find('title').text
    
### Equipo
    try:
        team = rider_soup.find('span', class_='red').text
    except:
        team = 'noteam'
    rider_infos["team"] = team   
        
    inter_soup = rider_soup.find('div', {"class":"rdr-info-cont"})
    
### Fecha nacimiento
    list_birthdate = inter_soup.contents[1:4]
    rider_infos["birthdate"] = list_birthdate[0] + list_birthdate[2][:-5]

### País    
    try:
        country = inter_soup.find('a', class_='black').text.encode('latin-1', 'ignore').decode('utf-8', 'ignore')
    except(UnicodeEncodeError):
        country = inter_soup.find('a', class_='black').text
    rider_infos["country"] = country

### Altura    
    try:
        height = float(inter_soup.find(string='Height:').next.split()[0])
    except:
        height = 0
    rider_infos["height"] = height    

### Peso        
    try:
        weight = float(inter_soup.find(string='Weight:').next.split()[0])
    except:
        weight = 0
    rider_infos["weight"] = weight

### Puntuaciones por especialidad
    try:
        specialties = inter_soup.find('div', class_='pps').find_all('li')
        for i in range(len(specialties)):
            specialty = specialties[i].find('a').text
            points = int(specialties[i].find('div', class_='pnt').text)
            rider_infos[specialty] = points
    except:
        pass

### Puntos ranking UCI
    try:
        uci_rank = inter_soup.find(string='UCI World').next.next.text
    except:
        uci_rank = 0
    rider_infos["UCI_rank"] = uci_rank

### URL
    rider_infos["rider_url"] = rider_url

### Devolvemos la información del ciclista
    print('Completado:', rider_infos["fullname"])
    return pd.DataFrame({"fullname": rider_infos["fullname"], "team": rider_infos["team"], 
                         "birthdate": rider_infos["birthdate"], "country": rider_infos["country"], 
                         "height": rider_infos["height"], "weight": rider_infos["weight"], 
                         "Onedayraces": rider_infos["Onedayraces"], "GC": rider_infos["GC"], 
                         "TT": rider_infos["TT"], "Sprint": rider_infos["Sprint"], 
                         "Climber": rider_infos["Climber"], "Hills": rider_infos["Hills"], 
                         "UCI-Rank": rider_infos["UCI_rank"], "rider_url": rider_infos["rider_url"]}, index=[0])

# %%
# Probamos a extraer datos de un ciclista
get_uniquerider_infos("https://www.procyclingstats.com/rider/kaden-groves")
# Out:
# Empezando petición a: https://www.procyclingstats.com/rider/kaden-groves
# Petición completada con éxito!
# Completado: Kaden  Groves
#          fullname                  team          birthdate    country  height  \
# 0  Kaden  Groves   Alpecin - Deceuninck   23 December 1998  Australia    1.76
#
#    weight  Onedayraces   GC   TT  Sprint  Climber  Hills UCI-Rank  \
# 0    76.0          421  246  357    1321      150   1664       36
#
#                                            rider_url
# 0  https://www.procyclingstats.com/rider/kaden-gr...

# %%
# Función para obtener la información de todos los ciclistas
# Utiliza el archivo creado con get_riders_urls
# Descarga cada página de ciclista y extrae la información
# Crea su propio archivo de información de ciclistas

def get_allriders_infos():
    '''Función para obtener la información de todos los ciclistas'''
    df_rider_urls = pd.read_csv("data/rider_urls.csv")
    df_rider_infos = pd.DataFrame(columns=["fullname", "team", "birthdate", "country", "height", "weight", "Onedayraces", "GC", "Sprint", "Climber", "TT", "Hills", "UCI-Rank", "rider_url"])
    for idx, row in df_rider_urls.iterrows():
        rider_url = row["rider_url"]
        rider_infos = get_uniquerider_infos(rider_url)
        df_rider_infos = pd.concat([df_rider_infos, rider_infos], ignore_index=True)
        df_rider_infos.to_csv("data/rider_infos.csv")
    print('Información de ciclistas obtenida')

# Obtenemos la información de todos los ciclistas
get_allriders_infos()
# Out:
# Empezando petición a: https://www.procyclingstats.com/rider/mathieu-van-der-poel
# Petición completada con éxito!
# Completado: Mathieu van der Poel
# Empezando petición a: https://www.procyclingstats.com/rider/jasper-philipsen
# C:\Users\andre\AppData\Local\Temp\ipykernel_19192\3396933871.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_rider_infos = pd.concat([df_rider_infos, rider_infos], ignore_index=True)
# Petición completada con éxito!
# Completado: Jasper  Philipsen
# Empezando petición a: https://www.procyclingstats.com/rider/soren-kragh-andersen
# Petición completada con éxito!
# Completado: Søren Kragh Andersen
# Empezando petición a: https://www.procyclingstats.com/rider/silvan-dillier
# Petición completada con éxito!
# Completado: Silvan  Dillier
# Empezando petición a: https://www.procyclingstats.com/rider/kaden-groves
# Petición completada con éxito!
# Completado: Kaden  Groves
# Empezando petición a: https://www.procyclingstats.com/rider/xandro-meurisse
# Petición completada con éxito!
# Completado: Xandro  Meurisse
# Empezando petición a: https://www.procyclingstats.com/rider/gianni-vermeersch
# Petición completada con éxito!
# Completado: Gianni  Vermeersch
# Empezando petición a: https://www.procyclingstats.com/rider/quinten-hermans
# Petición completada con éxito!
# Completado: Quinten  Hermans
# Empezando petición a: https://www.procyclingstats.com/rider/ramon-sinkeldam
# Petición completada con éxito!
# Completado: Ramon  Sinkeldam
# Empezando petición a: https://www.procyclingstats.com/rider/oscar-riesebeek
# Petición completada con éxito!
# Completado: Oscar  Riesebeek
# Empezando petición a: https://www.procyclingstats.com/rider/michael-gogl
# Petición completada con éxito!
# Completado: Michael  Gogl
# Empezando petición a: https://www.procyclingstats.com/rider/jonas-rickaert
# Petición completada con éxito!
# Completado: Jonas  Rickaert
# Empezando petición a: https://www.procyclingstats.com/rider/nicola-conci
# Petición completada con éxito!
# Completado: Nicola  Conci
# Empezando petición a: https://www.procyclingstats.com/rider/jimmy-janssens
# Petición completada con éxito!
# Completado: Jimmy  Janssens
# Empezando petición a: https://www.procyclingstats.com/rider/axel-laurance
# Petición completada con éxito!
# Completado: Axel  Laurance
# Empezando petición a: https://www.procyclingstats.com/rider/edward-planckaert
# Petición completada con éxito!
# Completado: Edward  Planckaert
# Empezando petición a: https://www.procyclingstats.com/rider/timo-kielich
# Petición completada con éxito!
# Completado: Timo  Kielich
# Empezando petición a: https://www.procyclingstats.com/rider/stan-van-tricht
# Petición completada con éxito!
# Completado: Stan Van Tricht
# Empezando petición a: https://www.procyclingstats.com/rider/tobias-bayer
# Petición completada con éxito!
# Completado: Tobias  Bayer
# Empezando petición a: https://www.procyclingstats.com/rider/robbe-ghys
# Petición completada con éxito!
# Completado: Robbe  Ghys
# Empezando petición a: https://www.procyclingstats.com/rider/jensen-plowright
# Petición completada con éxito!
# Completado: Jensen  Plowright
# Empezando petición a: https://www.procyclingstats.com/rider/senne-leysen
# Petición completada con éxito!
# Completado: Senne  Leysen
# Empezando petición a: https://www.procyclingstats.com/rider/maurice-ballerstedt
# Petición completada con éxito!
# Completado: Maurice  Ballerstedt
# Empezando petición a: https://www.procyclingstats.com/rider/fabio-van-den-bossche
# Petición completada con éxito!
# Completado: Fabio Van den Bossche
# Empezando petición a: https://www.procyclingstats.com/rider/juri-hollmann
# Petición completada con éxito!
# Completado: Juri  Hollmann
# Empezando petición a: https://www.procyclingstats.com/rider/henri-uhlig
# Petición completada con éxito!
# Completado: Henri  Uhlig
# Empezando petición a: https://www.procyclingstats.com/rider/lars-boven
# Petición completada con éxito!
# Completado: Lars  Boven
# Empezando petición a: https://www.procyclingstats.com/rider/luca-vergallito
# Petición completada con éxito!
# Completado: Luca  Vergallito
# Empezando petición a: https://www.procyclingstats.com/rider/jason-osborne
# Petición completada con éxito!
# Completado: Jason  Osborne
# Empezando petición a: https://www.procyclingstats.com/rider/arnaud-demare
# Petición completada con éxito!
# Completado: Arnaud  Démare
# Empezando petición a: https://www.procyclingstats.com/rider/florian-senechal
# Petición completada con éxito!
# Completado: Florian  Sénéchal
# Empezando petición a: https://www.procyclingstats.com/rider/clement-venturini
# Petición completada con éxito!
# Completado: Clément  Venturini
# Empezando petición a: https://www.procyclingstats.com/rider/amaury-capiot
# Petición completada con éxito!
# Completado: Amaury  Capiot
# Empezando petición a: https://www.procyclingstats.com/rider/anthony-delaplace
# Petición completada con éxito!
# Completado: Anthony  Delaplace
# Empezando petición a: https://www.procyclingstats.com/rider/luca-mozzato
# Petición completada con éxito!
# Completado: Luca  Mozzato
# Empezando petición a: https://www.procyclingstats.com/rider/daniel-mclay
# Petición completada con éxito!
# Completado: Daniel  McLay
# Empezando petición a: https://www.procyclingstats.com/rider/vincenzo-albanese
# Petición completada con éxito!
# Completado: Vincenzo  Albanese
# Empezando petición a: https://www.procyclingstats.com/rider/clement-champoussin
# Petición completada con éxito!
# Completado: Clément  Champoussin
# Empezando petición a: https://www.procyclingstats.com/rider/cristian-rodriguez
# Petición completada con éxito!
# Completado: Cristián  Rodríguez
# Empezando petición a: https://www.procyclingstats.com/rider/kevin-vauquelin
# Petición completada con éxito!
# Completado: Kévin  Vauquelin
# Empezando petición a: https://www.procyclingstats.com/rider/jenthe-biermans
# Petición completada con éxito!
# Completado: Jenthe  Biermans
# Empezando petición a: https://www.procyclingstats.com/rider/elie-gesbert
# Petición completada con éxito!
# Completado: Élie  Gesbert
# Empezando petición a: https://www.procyclingstats.com/rider/matis-louvel
# Petición completada con éxito!
# Completado: Matis  Louvel
# Empezando petición a: https://www.procyclingstats.com/rider/lukasz-owsian
# Petición completada con éxito!
# Completado: Łukasz  Owsian
# Empezando petición a: https://www.procyclingstats.com/rider/kevin-ledanois
# Petición completada con éxito!
# Completado: Kévin  Ledanois
# Empezando petición a: https://www.procyclingstats.com/rider/miles-scotson
# Petición completada con éxito!
# Completado: Miles  Scotson
# Empezando petición a: https://www.procyclingstats.com/rider/thibault-guernalec
# Petición completada con éxito!
# Completado: Thibault  Guernalec
# Empezando petición a: https://www.procyclingstats.com/rider/louis-barre
# Petición completada con éxito!
# Completado: Louis  Barré
# Empezando petición a: https://www.procyclingstats.com/rider/ewen-costiou
# Petición completada con éxito!
# Completado: Ewen  Costiou
# Empezando petición a: https://www.procyclingstats.com/rider/david-dekker
# Petición completada con éxito!
# Completado: David  Dekker
# Empezando petición a: https://www.procyclingstats.com/rider/raul-garcia-pierna
# Petición completada con éxito!
# Completado: Raúl  García Pierna
# Empezando petición a: https://www.procyclingstats.com/rider/simon-guglielmi
# Petición completada con éxito!
# Completado: Simon  Guglielmi
# Empezando petición a: https://www.procyclingstats.com/rider/laurens-huys
# Petición completada con éxito!
# Completado: Laurens  Huys
# Empezando petición a: https://www.procyclingstats.com/rider/michel-ries
# Petición completada con éxito!
# Completado: Michel  Ries
# Empezando petición a: https://www.procyclingstats.com/rider/alan-riou
# Petición completada con éxito!
# Completado: Alan  Riou
# Empezando petición a: https://www.procyclingstats.com/rider/alessandro-verre
# Petición completada con éxito!
# Completado: Alessandro  Verre
# Empezando petición a: https://www.procyclingstats.com/rider/mathis-le-berre
# Petición completada con éxito!
# Completado: Mathis Le Berre
# Empezando petición a: https://www.procyclingstats.com/rider/donavan-grondin
# Petición completada con éxito!
# Completado: Donavan  Grondin
# Empezando petición a: https://www.procyclingstats.com/rider/geraint-thomas
# Petición completada con éxito!
# Completado: Geraint  Thomas
# Empezando petición a: https://www.procyclingstats.com/rider/elia-viviani
# Petición completada con éxito!
# Completado: Elia  Viviani
# Empezando petición a: https://www.procyclingstats.com/rider/michal-kwiatkowski
# Petición completada con éxito!
# Completado: Michał  Kwiatkowski
# Empezando petición a: https://www.procyclingstats.com/rider/egan-bernal
# Petición completada con éxito!
# Completado: Egan  Bernal
# Empezando petición a: https://www.procyclingstats.com/rider/filippo-ganna
# Petición completada con éxito!
# Completado: Filippo  Ganna
# Empezando petición a: https://www.procyclingstats.com/rider/ben-swift
# Petición completada con éxito!
# Completado: Ben  Swift
# Empezando petición a: https://www.procyclingstats.com/rider/jonathan-castroviejo
# Petición completada con éxito!
# Completado: Jonathan  Castroviejo
# Empezando petición a: https://www.procyclingstats.com/rider/thomas-pidcock
# Petición completada con éxito!
# Completado: Thomas  Pidcock
# Empezando petición a: https://www.procyclingstats.com/rider/carlos-rodriguez-cano
# Petición completada con éxito!
# Completado: Carlos  Rodríguez
# Empezando petición a: https://www.procyclingstats.com/rider/ethan-hayter
# Petición completada con éxito!
# Completado: Ethan  Hayter
# Empezando petición a: https://www.procyclingstats.com/rider/jhonatan-narvaez
# Petición completada con éxito!
# Completado: Jhonatan  Narváez
# Empezando petición a: https://www.procyclingstats.com/rider/thymen-arensman
# Petición completada con éxito!
# Completado: Thymen  Arensman
# Empezando petición a: https://www.procyclingstats.com/rider/laurens-de-plus
# Petición completada con éxito!
# Completado: Laurens De Plus
# Empezando petición a: https://www.procyclingstats.com/rider/luke-rowe
# Petición completada con éxito!
# Completado: Luke  Rowe
# Empezando petición a: https://www.procyclingstats.com/rider/omar-fraile
# Petición completada con éxito!
# Completado: Omar  Fraile
# Empezando petición a: https://www.procyclingstats.com/rider/magnus-sheffield
# Petición completada con éxito!
# Completado: Magnus  Sheffield
# Empezando petición a: https://www.procyclingstats.com/rider/tobias-foss
# Petición completada con éxito!
# Completado: Tobias  Foss
# Empezando petición a: https://www.procyclingstats.com/rider/salvatore-puccio
# Petición completada con éxito!
# Completado: Salvatore  Puccio
# Empezando petición a: https://www.procyclingstats.com/rider/connor-swift
# Petición completada con éxito!
# Completado: Connor  Swift
# Empezando petición a: https://www.procyclingstats.com/rider/oscar-rodriguez
# Petición completada con éxito!
# Completado: Óscar  Rodríguez
# Empezando petición a: https://www.procyclingstats.com/rider/joshua-tarling
# Petición completada con éxito!
# Completado: Joshua  Tarling
# Empezando petición a: https://www.procyclingstats.com/rider/cameron-wurf
# Petición completada con éxito!
# Completado: Cameron  Wurf
# Empezando petición a: https://www.procyclingstats.com/rider/ben-turner
# Petición completada con éxito!
# Completado: Ben  Turner
# Empezando petición a: https://www.procyclingstats.com/rider/brandon-smith-rivera-vargas
# Petición completada con éxito!
# Completado: Brandon Smith  Rivera
# Empezando petición a: https://www.procyclingstats.com/rider/kim-heiduk
# Petición completada con éxito!
# Completado: Kim  Heiduk
# Empezando petición a: https://www.procyclingstats.com/rider/leo-hayter
# Petición completada con éxito!
# Completado: Leo  Hayter
# Empezando petición a: https://www.procyclingstats.com/rider/andrew-august
# Petición completada con éxito!
# Completado: Andrew  August
# Empezando petición a: https://www.procyclingstats.com/rider/michael-leonard1
# Petición completada con éxito!
# Completado: Michael  Leonard
# Empezando petición a: https://www.procyclingstats.com/rider/artem-shmidt
# Petición completada con éxito!
# Completado: Artem  Shmidt
# Empezando petición a: https://www.procyclingstats.com/rider/mark-cavendish
# Petición completada con éxito!
# Completado: Mark  Cavendish
# Empezando petición a: https://www.procyclingstats.com/rider/aleksey-lutsenko
# Petición completada con éxito!
# Completado: Alexey  Lutsenko
# Empezando petición a: https://www.procyclingstats.com/rider/alberto-bettiol
# Petición completada con éxito!
# Completado: Alberto  Bettiol
# Empezando petición a: https://www.procyclingstats.com/rider/michael-morkov
# Petición completada con éxito!
# Completado: Michael  Mørkøv
# Empezando petición a: https://www.procyclingstats.com/rider/davide-ballerini
# Petición completada con éxito!
# Completado: Davide  Ballerini
# Empezando petición a: https://www.procyclingstats.com/rider/simone-velasco
# Petición completada con éxito!
# Completado: Simone  Velasco
# Empezando petición a: https://www.procyclingstats.com/rider/cees-bol
# Petición completada con éxito!
# Completado: Cees  Bol
# Empezando petición a: https://www.procyclingstats.com/rider/dmitriy-gruzdev
# Petición completada con éxito!
# Completado: Dmitriy  Gruzdev
# Empezando petición a: https://www.procyclingstats.com/rider/rudiger-selig
# Petición completada con éxito!
# Completado: Rüdiger  Selig
# Empezando petición a: https://www.procyclingstats.com/rider/lorenzo-fortunato
# Petición completada con éxito!
# Completado: Lorenzo  Fortunato
# Empezando petición a: https://www.procyclingstats.com/rider/henok-mulubrhan
# Petición completada con éxito!
# Completado: Henok  Mulubrhan
# Empezando petición a: https://www.procyclingstats.com/rider/yevgeniy-gidich
# Petición completada con éxito!
# Completado: Yevgeniy  Gidich
# Empezando petición a: https://www.procyclingstats.com/rider/max-kanter
# Petición completada con éxito!
# Completado: Max  Kanter
# Empezando petición a: https://www.procyclingstats.com/rider/samuele-battistella
# Petición completada con éxito!
# Completado: Samuele  Battistella
# Empezando petición a: https://www.procyclingstats.com/rider/yevgeniy-fedorov
# Petición completada con éxito!
# Completado: Yevgeniy  Fedorov
# Empezando petición a: https://www.procyclingstats.com/rider/ide-schelling
# Petición completada con éxito!
# Completado: Ide  Schelling
# Empezando petición a: https://www.procyclingstats.com/rider/christian-scaroni
# Petición completada con éxito!
# Completado: Christian  Scaroni
# Empezando petición a: https://www.procyclingstats.com/rider/harold-tejada
# Petición completada con éxito!
# Completado: Harold  Tejada
# Empezando petición a: https://www.procyclingstats.com/rider/vadim-pronskiy
# Petición completada con éxito!
# Completado: Vadim  Pronskiy
# Empezando petición a: https://www.procyclingstats.com/rider/anthon-charmig
# Petición completada con éxito!
# Completado: Anthon  Charmig
# Empezando petición a: https://www.procyclingstats.com/rider/gleb-syritsa
# Petición completada con éxito!
# Completado: Gleb  Syritsa
# Empezando petición a: https://www.procyclingstats.com/rider/igor-chzhan
# Petición completada con éxito!
# Completado: Igor  Chzhan
# Empezando petición a: https://www.procyclingstats.com/rider/gleb-brussenskiy
# Petición completada con éxito!
# Completado: Gleb  Brussenskiy
# Empezando petición a: https://www.procyclingstats.com/rider/harold-martin-lopez
# Petición completada con éxito!
# Completado: Harold Martín  López
# Empezando petición a: https://www.procyclingstats.com/rider/anton-kuzmin
# Petición completada con éxito!
# Completado: Anton  Kuzmin
# Empezando petición a: https://www.procyclingstats.com/rider/daniil-marukhin
# Petición completada con éxito!
# Completado: Daniil  Marukhin
# Empezando petición a: https://www.procyclingstats.com/rider/michele-gazzoli
# Petición completada con éxito!
# Completado: Michele  Gazzoli
# Empezando petición a: https://www.procyclingstats.com/rider/santiago-umba
# Petición completada con éxito!
# Completado: Santiago  Umba
# Empezando petición a: https://www.procyclingstats.com/rider/gianmarco-garofoli
# Petición completada con éxito!
# Completado: Gianmarco  Garofoli
# Empezando petición a: https://www.procyclingstats.com/rider/wout-poels
# Petición completada con éxito!
# Completado: Wout  Poels
# Empezando petición a: https://www.procyclingstats.com/rider/pello-bilbao
# Petición completada con éxito!
# Completado: Pello  Bilbao
# Empezando petición a: https://www.procyclingstats.com/rider/damiano-caruso
# Petición completada con éxito!
# Completado: Damiano  Caruso
# Empezando petición a: https://www.procyclingstats.com/rider/matej-mohoric
# Petición completada con éxito!
# Completado: Matej  Mohorič
# Empezando petición a: https://www.procyclingstats.com/rider/andrea-pasqualon
# Petición completada con éxito!
# Completado: Andrea  Pasqualon
# Empezando petición a: https://www.procyclingstats.com/rider/jack-haig
# Petición completada con éxito!
# Completado: Jack  Haig
# Empezando petición a: https://www.procyclingstats.com/rider/yukiya-arashiro
# Petición completada con éxito!
# Completado: Yukiya  Arashiro
# Empezando petición a: https://www.procyclingstats.com/rider/phil-bauhaus
# Petición completada con éxito!
# Completado: Phil  Bauhaus
# Empezando petición a: https://www.procyclingstats.com/rider/nikias-arndt
# Petición completada con éxito!
# Completado: Nikias  Arndt
# Empezando petición a: https://www.procyclingstats.com/rider/santiago-buitrago-sanchez
# Petición completada con éxito!
# Completado: Santiago  Buitrago
# Empezando petición a: https://www.procyclingstats.com/rider/antonio-tiberi
# Petición completada con éxito!
# Completado: Antonio  Tiberi
# Empezando petición a: https://www.procyclingstats.com/rider/jasha-sutterlin
# Petición completada con éxito!
# Completado: Jasha  Sütterlin
# Empezando petición a: https://www.procyclingstats.com/rider/alfred-wright
# Petición completada con éxito!
# Completado: Fred  Wright
# Empezando petición a: https://www.procyclingstats.com/rider/kamil-gradek
# Petición completada con éxito!
# Completado: Kamil  Gradek
# Empezando petición a: https://www.procyclingstats.com/rider/lukasz-wisniowski
# Petición completada con éxito!
# Completado: Łukasz  Wiśniowski
# Empezando petición a: https://www.procyclingstats.com/rider/torstein-traeen
# Petición completada con éxito!
# Completado: Torstein  Træen
# Empezando petición a: https://www.procyclingstats.com/rider/edoardo-zambanini
# Petición completada con éxito!
# Completado: Edoardo  Zambanini
# Empezando petición a: https://www.procyclingstats.com/rider/dusan-rajovic
# Petición completada con éxito!
# Completado: Dušan  Rajović
# Empezando petición a: https://www.procyclingstats.com/rider/matevz-govekar
# Petición completada con éxito!
# Completado: Matevž  Govekar
# Empezando petición a: https://www.procyclingstats.com/rider/robert-stannard
# Petición completada con éxito!
# Completado: Robert  Stannard
# Empezando petición a: https://www.procyclingstats.com/rider/rainer-kepplinger
# Petición completada con éxito!
# Completado: Rainer  Kepplinger
# Empezando petición a: https://www.procyclingstats.com/rider/fran-miholjevic
# Petición completada con éxito!
# Completado: Fran  Miholjević
# Empezando petición a: https://www.procyclingstats.com/rider/johan-price-pejtersen
# Petición completada con éxito!
# Completado: Johan  Price-Pejtersen
# Empezando petición a: https://www.procyclingstats.com/rider/nicolo-buratti
# Petición completada con éxito!
# Completado: Nicolò  Buratti
# Empezando petición a: https://www.procyclingstats.com/rider/chih-hao-tu
# Petición completada con éxito!
# Completado: Sergio  Tu
# Empezando petición a: https://www.procyclingstats.com/rider/cameron-scott
# Petición completada con éxito!
# Completado: Cameron  Scott
# Empezando petición a: https://www.procyclingstats.com/rider/ahmed-madan
# Petición completada con éxito!
# Completado: Ahmed  Madan
# Empezando petición a: https://www.procyclingstats.com/rider/alberto-bruttomesso
# Petición completada con éxito!
# Completado: Alberto  Bruttomesso
# Empezando petición a: https://www.procyclingstats.com/rider/daniel-skerl
# Petición completada con éxito!
# Completado: Daniel  Skerl
# Empezando petición a: https://www.procyclingstats.com/rider/primoz-roglic
# Petición completada con éxito!
# Completado: Primož  Roglič
# Empezando petición a: https://www.procyclingstats.com/rider/danny-van-poppel
# Petición completada con éxito!
# Completado: Danny van Poppel
# Empezando petición a: https://www.procyclingstats.com/rider/aleksandr-vlasov
# Petición completada con éxito!
# Completado: Aleksandr  Vlasov
# Empezando petición a: https://www.procyclingstats.com/rider/bob-jungels
# Petición completada con éxito!
# Completado: Bob  Jungels
# Empezando petición a: https://www.procyclingstats.com/rider/daniel-felipe-martinez
# Petición completada con éxito!
# Completado: Daniel Felipe  Martínez
# Empezando petición a: https://www.procyclingstats.com/rider/maximilian-schachmann
# Petición completada con éxito!
# Completado: Maximilian  Schachmann
# Empezando petición a: https://www.procyclingstats.com/rider/emanuel-buchmann
# Petición completada con éxito!
# Completado: Emanuel  Buchmann
# Empezando petición a: https://www.procyclingstats.com/rider/jai-hindley
# Petición completada con éxito!
# Completado: Jai  Hindley
# Empezando petición a: https://www.procyclingstats.com/rider/sergio-higuita
# Petición completada con éxito!
# Completado: Sergio  Higuita
# Empezando petición a: https://www.procyclingstats.com/rider/jordi-meeus
# Petición completada con éxito!
# Completado: Jordi  Meeus
# Empezando petición a: https://www.procyclingstats.com/rider/lennard-kamna
# Petición completada con éxito!
# Completado: Lennard  Kämna
# Empezando petición a: https://www.procyclingstats.com/rider/marco-haller
# Petición completada con éxito!
# Completado: Marco  Haller
# Empezando petición a: https://www.procyclingstats.com/rider/giovanni-aleotti
# Petición completada con éxito!
# Completado: Giovanni  Aleotti
# Empezando petición a: https://www.procyclingstats.com/rider/roger-adria
# Petición completada con éxito!
# Completado: Roger  Adrià
# Empezando petición a: https://www.procyclingstats.com/rider/nico-denz
# Petición completada con éxito!
# Completado: Nico  Denz
# Empezando petición a: https://www.procyclingstats.com/rider/matteo-sobrero
# Petición completada con éxito!
# Completado: Matteo  Sobrero
# Empezando petición a: https://www.procyclingstats.com/rider/jonas-koch
# Petición completada con éxito!
# Completado: Jonas  Koch
# Empezando petición a: https://www.procyclingstats.com/rider/sam-welsford
# Petición completada con éxito!
# Completado: Sam  Welsford
# Empezando petición a: https://www.procyclingstats.com/rider/cesare-benedetti
# Petición completada con éxito!
# Completado: Cesare  Benedetti
# Empezando petición a: https://www.procyclingstats.com/rider/ryan-mullen
# Petición completada con éxito!
# Completado: Ryan  Mullen
# Empezando petición a: https://www.procyclingstats.com/rider/florian-lipowitz
# Petición completada con éxito!
# Completado: Florian  Lipowitz
# Empezando petición a: https://www.procyclingstats.com/rider/ben-zwiehoff
# Petición completada con éxito!
# Completado: Ben  Zwiehoff
# Empezando petición a: https://www.procyclingstats.com/rider/frederik-wandahl
# Petición completada con éxito!
# Completado: Frederik  Wandahl
# Empezando petición a: https://www.procyclingstats.com/rider/patrick-gamper
# Petición completada con éxito!
# Completado: Patrick  Gamper
# Empezando petición a: https://www.procyclingstats.com/rider/filip-maciejuk
# Petición completada con éxito!
# Completado: Filip  Maciejuk
# Empezando petición a: https://www.procyclingstats.com/rider/alexander-hajek
# Petición completada con éxito!
# Completado: Alexander  Hajek
# Empezando petición a: https://www.procyclingstats.com/rider/anton-palzer
# Petición completada con éxito!
# Completado: Anton  Palzer
# Empezando petición a: https://www.procyclingstats.com/rider/emil-herzog
# Petición completada con éxito!
# Completado: Emil  Herzog
# Empezando petición a: https://www.procyclingstats.com/rider/luis-joe-luhrs
# Petición completada con éxito!
# Completado: Luis-Joe  Lührs
# Empezando petición a: https://www.procyclingstats.com/rider/ion-izagirre
# Petición completada con éxito!
# Completado: Ion  Izagirre
# Empezando petición a: https://www.procyclingstats.com/rider/bryan-coquard
# Petición completada con éxito!
# Completado: Bryan  Coquard
# Empezando petición a: https://www.procyclingstats.com/rider/guillaume-martin
# Petición completada con éxito!
# Completado: Guillaume  Martin
# Empezando petición a: https://www.procyclingstats.com/rider/ben-hermans
# Petición completada con éxito!
# Completado: Ben  Hermans
# Empezando petición a: https://www.procyclingstats.com/rider/jesus-herrada-lopez
# Petición completada con éxito!
# Completado: Jesús  Herrada
# Empezando petición a: https://www.procyclingstats.com/rider/gorka-izagirre
# Petición completada con éxito!
# Completado: Gorka  Izagirre
# Empezando petición a: https://www.procyclingstats.com/rider/simon-geschke
# Petición completada con éxito!
# Completado: Simon  Geschke
# Empezando petición a: https://www.procyclingstats.com/rider/axel-zingle
# Petición completada con éxito!
# Completado: Axel  Zingle
# Empezando petición a: https://www.procyclingstats.com/rider/kenny-elissonde
# Petición completada con éxito!
# Completado: Kenny  Elissonde
# Empezando petición a: https://www.procyclingstats.com/rider/ruben-fernandez
# Petición completada con éxito!
# Completado: Rubén  Fernández
# Empezando petición a: https://www.procyclingstats.com/rider/benjamin-thomas-2
# Petición completada con éxito!
# Completado: Benjamin  Thomas
# Empezando petición a: https://www.procyclingstats.com/rider/aime-de-gendt
# Petición completada con éxito!
# Completado: Aimé De Gendt
# Empezando petición a: https://www.procyclingstats.com/rider/piet-allegaert
# Petición completada con éxito!
# Completado: Piet  Allegaert
# Empezando petición a: https://www.procyclingstats.com/rider/alexis-gougeard
# Petición completada con éxito!
# Completado: Alexis  Gougeard
# Empezando petición a: https://www.procyclingstats.com/rider/stanislaw-aniolkowski
# Petición completada con éxito!
# Completado: Stanisław  Aniołkowski
# Empezando petición a: https://www.procyclingstats.com/rider/jonathan-lastra
# Petición completada con éxito!
# Completado: Jonathan  Lastra
# Empezando petición a: https://www.procyclingstats.com/rider/anthony-perez
# Petición completada con éxito!
# Completado: Anthony  Perez
# Empezando petición a: https://www.procyclingstats.com/rider/stefano-oldani
# Petición completada con éxito!
# Completado: Stefano  Oldani
# Empezando petición a: https://www.procyclingstats.com/rider/christophe-noppe
# Petición completada con éxito!
# Completado: Christophe  Noppe
# Empezando petición a: https://www.procyclingstats.com/rider/milan-fretin
# Petición completada con éxito!
# Completado: Milan  Fretin
# Empezando petición a: https://www.procyclingstats.com/rider/alexis-renard
# Petición completada con éxito!
# Completado: Alexis  Renard
# Empezando petición a: https://www.procyclingstats.com/rider/ludovic-robeet
# Petición completada con éxito!
# Completado: Ludovic  Robeet
# Empezando petición a: https://www.procyclingstats.com/rider/axel-mariault
# Petición completada con éxito!
# Completado: Axel  Mariault
# Empezando petición a: https://www.procyclingstats.com/rider/eddy-fine
# Petición completada con éxito!
# Completado: Eddy  Finé
# Empezando petición a: https://www.procyclingstats.com/rider/thomas-champion
# Petición completada con éxito!
# Completado: Thomas  Champion
# Empezando petición a: https://www.procyclingstats.com/rider/harrison-wood
# Petición completada con éxito!
# Completado: Harrison  Wood
# Empezando petición a: https://www.procyclingstats.com/rider/hugo-toumire
# Petición completada con éxito!
# Completado: Hugo  Toumire
# Empezando petición a: https://www.procyclingstats.com/rider/nicolas-debeaumarche
# Petición completada con éxito!
# Completado: Nicolas  Debeaumarché
# Empezando petición a: https://www.procyclingstats.com/rider/nolann-mahoudo
# Petición completada con éxito!
# Completado: Nolann  Mahoudo
# Empezando petición a: https://www.procyclingstats.com/rider/edvald-boasson-hagen
# Petición completada con éxito!
# Completado: Edvald  Boasson Hagen
# Empezando petición a: https://www.procyclingstats.com/rider/sam-bennett
# Petición completada con éxito!
# Completado: Sam  Bennett
# Empezando petición a: https://www.procyclingstats.com/rider/oliver-naesen
# Petición completada con éxito!
# Completado: Oliver  Naesen
# Empezando petición a: https://www.procyclingstats.com/rider/ben-o-connor
# Petición completada con éxito!
# Completado: Ben  O'Connor
# Empezando petición a: https://www.procyclingstats.com/rider/benoit-cosnefroy
# Petición completada con éxito!
# Completado: Benoît  Cosnefroy
# Empezando petición a: https://www.procyclingstats.com/rider/andrea-vendrame
# Petición completada con éxito!
# Completado: Andrea  Vendrame
# Empezando petición a: https://www.procyclingstats.com/rider/aurelien-paret-peintre
# Petición completada con éxito!
# Completado: Aurélien  Paret-Peintre
# Empezando petición a: https://www.procyclingstats.com/rider/dorian-godon
# Petición completada con éxito!
# Completado: Dorian  Godon
# Empezando petición a: https://www.procyclingstats.com/rider/dries-de-bondt
# Petición completada con éxito!
# Completado: Dries De Bondt
# Empezando petición a: https://www.procyclingstats.com/rider/felix-gall
# Petición completada con éxito!
# Completado: Felix  Gall
# Empezando petición a: https://www.procyclingstats.com/rider/stan-dewulf
# Petición completada con éxito!
# Completado: Stan  Dewulf
# Empezando petición a: https://www.procyclingstats.com/rider/nans-peters
# Petición completada con éxito!
# Completado: Nans  Peters
# Empezando petición a: https://www.procyclingstats.com/rider/lawrence-warbasse
# Petición completada con éxito!
# Completado: Larry  Warbasse
# Empezando petición a: https://www.procyclingstats.com/rider/victor-lafay
# Petición completada con éxito!
# Completado: Victor  Lafay
# Empezando petición a: https://www.procyclingstats.com/rider/franck-bonnamour
# Petición completada con éxito!
# Completado: Franck  Bonnamour
# Empezando petición a: https://www.procyclingstats.com/rider/geoffrey-bouchard
# Petición completada con éxito!
# Completado: Geoffrey  Bouchard
# Empezando petición a: https://www.procyclingstats.com/rider/bruno-armirail
# Petición completada con éxito!
# Completado: Bruno  Armirail
# Empezando petición a: https://www.procyclingstats.com/rider/damien-touze
# Petición completada con éxito!
# Completado: Damien  Touzé
# Empezando petición a: https://www.procyclingstats.com/rider/clement-berthet
# Petición completada con éxito!
# Completado: Clément  Berthet
# Empezando petición a: https://www.procyclingstats.com/rider/paul-lapeira
# Petición completada con éxito!
# Completado: Paul  Lapeira
# Empezando petición a: https://www.procyclingstats.com/rider/valentin-paret-peintre
# Petición completada con éxito!
# Completado: Valentin  Paret-Peintre
# Empezando petición a: https://www.procyclingstats.com/rider/nicolas-prodhomme
# Petición completada con éxito!
# Completado: Nicolas  Prodhomme
# Empezando petición a: https://www.procyclingstats.com/rider/pierre-gautherat
# Petición completada con éxito!
# Completado: Pierre  Gautherat
# Empezando petición a: https://www.procyclingstats.com/rider/alex-baudin
# Petición completada con éxito!
# Completado: Alex  Baudin
# Empezando petición a: https://www.procyclingstats.com/rider/jaakko-hanninen
# Petición completada con éxito!
# Completado: Jaakko  Hänninen
# Empezando petición a: https://www.procyclingstats.com/rider/bastien-tronchon
# Petición completada con éxito!
# Completado: Bastien  Tronchon
# Empezando petición a: https://www.procyclingstats.com/rider/sander-de-pestel
# Petición completada con éxito!
# Completado: Sander De Pestel
# Empezando petición a: https://www.procyclingstats.com/rider/valentin-retailleau
# Petición completada con éxito!
# Completado: Valentin  Retailleau
# Empezando petición a: https://www.procyclingstats.com/rider/jordan-labrosse
# Petición completada con éxito!
# Completado: Jordan  Labrosse
# Empezando petición a: https://www.procyclingstats.com/rider/rui-costa
# Petición completada con éxito!
# Completado: Rui  Costa
# Empezando petición a: https://www.procyclingstats.com/rider/rigoberto-uran
# Petición completada con éxito!
# Completado: Rigoberto  Urán
# Empezando petición a: https://www.procyclingstats.com/rider/richard-carapaz
# Petición completada con éxito!
# Completado: Richard  Carapaz
# Empezando petición a: https://www.procyclingstats.com/rider/johan-esteban-chaves
# Petición completada con éxito!
# Completado: Esteban  Chaves
# Empezando petición a: https://www.procyclingstats.com/rider/michael-valgren-andersen
# Petición completada con éxito!
# Completado: Michael  Valgren
# Empezando petición a: https://www.procyclingstats.com/rider/hugh-carthy
# Petición completada con éxito!
# Completado: Hugh  Carthy
# Empezando petición a: https://www.procyclingstats.com/rider/neilson-powless
# Petición completada con éxito!
# Completado: Neilson  Powless
# Empezando petición a: https://www.procyclingstats.com/rider/andrey-amador
# Petición completada con éxito!
# Completado: Andrey  Amador
# Empezando petición a: https://www.procyclingstats.com/rider/mikkel-honore
# Petición completada con éxito!
# Completado: Mikkel Frølich  Honoré
# Empezando petición a: https://www.procyclingstats.com/rider/ben-healy
# Petición completada con éxito!
# Completado: Ben  Healy
# Empezando petición a: https://www.procyclingstats.com/rider/stefan-bissegger
# Petición completada con éxito!
# Completado: Stefan  Bissegger
# Empezando petición a: https://www.procyclingstats.com/rider/marijn-van-den-berg
# Petición completada con éxito!
# Completado: Marijn van den Berg
# Empezando petición a: https://www.procyclingstats.com/rider/owain-doull
# Petición completada con éxito!
# Completado: Owain  Doull
# Empezando petición a: https://www.procyclingstats.com/rider/stefan-de-bod
# Petición completada con éxito!
# Completado: Stefan de Bod
# Empezando petición a: https://www.procyclingstats.com/rider/jefferson-alexander-cepeda
# Petición completada con éxito!
# Completado: Jefferson Alexander  Cepeda
# Empezando petición a: https://www.procyclingstats.com/rider/simon-carr
# Petición completada con éxito!
# Completado: Simon  Carr
# Empezando petición a: https://www.procyclingstats.com/rider/james-shaw
# Petición completada con éxito!
# Completado: James  Shaw
# Empezando petición a: https://www.procyclingstats.com/rider/jonas-rutsch
# Petición completada con éxito!
# Completado: Jonas  Rutsch
# Empezando petición a: https://www.procyclingstats.com/rider/andrea-piccolo
# Petición completada con éxito!
# Completado: Andrea  Piccolo
# Empezando petición a: https://www.procyclingstats.com/rider/georg-steinhauser
# Petición completada con éxito!
# Completado: Georg  Steinhauser
# Empezando petición a: https://www.procyclingstats.com/rider/archie-ryan
# Petición completada con éxito!
# Completado: Archie  Ryan
# Empezando petición a: https://www.procyclingstats.com/rider/harry-sweeny
# Petición completada con éxito!
# Completado: Harry  Sweeny
# Empezando petición a: https://www.procyclingstats.com/rider/sean-quinn
# Petición completada con éxito!
# Completado: Sean  Quinn
# Empezando petición a: https://www.procyclingstats.com/rider/lukas-nerurkar
# Petición completada con éxito!
# Completado: Lukas  Nerurkar
# Empezando petición a: https://www.procyclingstats.com/rider/darren-rafferty
# Petición completada con éxito!
# Completado: Darren  Rafferty
# Empezando petición a: https://www.procyclingstats.com/rider/jack-rootkin-gray
# Petición completada con éxito!
# Completado: Jack  Rootkin-Gray
# Empezando petición a: https://www.procyclingstats.com/rider/jardi-christiaan-van-der-lee
# Petición completada con éxito!
# Completado: Jardi Christiaan van der Lee
# Empezando petición a: https://www.procyclingstats.com/rider/edvin-lovidius
# Petición completada con éxito!
# Completado: Edvin  Lovidius
# Empezando petición a: https://www.procyclingstats.com/rider/stefan-kung
# Petición completada con éxito!
# Completado: Stefan  Küng
# Empezando petición a: https://www.procyclingstats.com/rider/david-gaudu
# Petición completada con éxito!
# Completado: David  Gaudu
# Empezando petición a: https://www.procyclingstats.com/rider/valentin-madouas
# Petición completada con éxito!
# Completado: Valentin  Madouas
# Empezando petición a: https://www.procyclingstats.com/rider/rudy-molard
# Petición completada con éxito!
# Completado: Rudy  Molard
# Empezando petición a: https://www.procyclingstats.com/rider/marc-sarreau
# Petición completada con éxito!
# Completado: Marc  Sarreau
# Empezando petición a: https://www.procyclingstats.com/rider/quentin-pacher
# Petición completada con éxito!
# Completado: Quentin  Pacher
# Empezando petición a: https://www.procyclingstats.com/rider/ignatas-konovalovas
# Petición completada con éxito!
# Completado: Ignatas  Konovalovas
# Empezando petición a: https://www.procyclingstats.com/rider/sven-erik-bystrom
# Petición completada con éxito!
# Completado: Sven Erik  Bystrøm
# Empezando petición a: https://www.procyclingstats.com/rider/romain-gregoire1
# Petición completada con éxito!
# Completado: Romain  Grégoire
# Empezando petición a: https://www.procyclingstats.com/rider/lenny-martinez
# Petición completada con éxito!
# Completado: Lenny  Martinez
# Empezando petición a: https://www.procyclingstats.com/rider/paul-penhoet
# Petición completada con éxito!
# Completado: Paul  Penhoët
# Empezando petición a: https://www.procyclingstats.com/rider/laurence-pithie
# Petición completada con éxito!
# Completado: Laurence  Pithie
# Empezando petición a: https://www.procyclingstats.com/rider/olivier-le-gac
# Petición completada con éxito!
# Completado: Olivier Le Gac
# Empezando petición a: https://www.procyclingstats.com/rider/kevin-geniets
# Petición completada con éxito!
# Completado: Kevin  Geniets
# Empezando petición a: https://www.procyclingstats.com/rider/fabian-lienhard
# Petición completada con éxito!
# Completado: Fabian  Lienhard
# Empezando petición a: https://www.procyclingstats.com/rider/remy-rochas
# Petición completada con éxito!
# Completado: Rémy  Rochas
# Empezando petición a: https://www.procyclingstats.com/rider/clement-russo
# Petición completada con éxito!
# Completado: Clément  Russo
# Empezando petición a: https://www.procyclingstats.com/rider/lewis-askey
# Petición completada con éxito!
# Completado: Lewis  Askey
# Empezando petición a: https://www.procyclingstats.com/rider/cyril-barthe
# Petición completada con éxito!
# Completado: Cyril  Barthe
# Empezando petición a: https://www.procyclingstats.com/rider/samuel-watson
# Petición completada con éxito!
# Completado: Samuel  Watson
# Empezando petición a: https://www.procyclingstats.com/rider/matthew-walls
# Petición completada con éxito!
# Completado: Matthew  Walls
# Empezando petición a: https://www.procyclingstats.com/rider/reuben-thompson
# Petición completada con éxito!
# Completado: Reuben  Thompson
# Empezando petición a: https://www.procyclingstats.com/rider/lars-van-den-berg
# Petición completada con éxito!
# Completado: Lars van den Berg
# Empezando petición a: https://www.procyclingstats.com/rider/enzo-paleni
# Petición completada con éxito!
# Completado: Enzo  Paleni
# Empezando petición a: https://www.procyclingstats.com/rider/lorenzo-germani
# Petición completada con éxito!
# Completado: Lorenzo  Germani
# Empezando petición a: https://www.procyclingstats.com/rider/clement-davy
# Petición completada con éxito!
# Completado: Clément  Davy
# Empezando petición a: https://www.procyclingstats.com/rider/thibaud-gruel
# Petición completada con éxito!
# Completado: Thibaud  Gruel
# Empezando petición a: https://www.procyclingstats.com/rider/eddy-le-huitouze
# Petición completada con éxito!
# Completado: Eddy Le Huitouze
# Empezando petición a: https://www.procyclingstats.com/rider/bauke-mollema
# Petición completada con éxito!
# Completado: Bauke  Mollema
# Empezando petición a: https://www.procyclingstats.com/rider/mads-pedersen
# Petición completada con éxito!
# Completado: Mads  Pedersen
# Empezando petición a: https://www.procyclingstats.com/rider/jasper-stuyven
# Petición completada con éxito!
# Completado: Jasper  Stuyven
# Empezando petición a: https://www.procyclingstats.com/rider/patrick-konrad
# Petición completada con éxito!
# Completado: Patrick  Konrad
# Empezando petición a: https://www.procyclingstats.com/rider/edward-theuns
# Petición completada con éxito!
# Completado: Edward  Theuns
# Empezando petición a: https://www.procyclingstats.com/rider/fabio-felline
# Petición completada con éxito!
# Completado: Fabio  Felline
# Empezando petición a: https://www.procyclingstats.com/rider/toms-skujins
# Petición completada con éxito!
# Completado: Toms  Skujiņš
# Empezando petición a: https://www.procyclingstats.com/rider/giulio-ciccone
# Petición completada con éxito!
# Completado: Giulio  Ciccone
# Empezando petición a: https://www.procyclingstats.com/rider/mattias-skjelmose-jensen
# Petición completada con éxito!
# Completado: Mattias  Skjelmose
# Empezando petición a: https://www.procyclingstats.com/rider/tao-geoghegan-hart
# Petición completada con éxito!
# Completado: Tao  Geoghegan Hart
# Empezando petición a: https://www.procyclingstats.com/rider/dario-cataldo
# Petición completada con éxito!
# Completado: Dario  Cataldo
# Empezando petición a: https://www.procyclingstats.com/rider/simone-consonni
# Petición completada con éxito!
# Completado: Simone  Consonni
# Empezando petición a: https://www.procyclingstats.com/rider/sam-oomen
# Petición completada con éxito!
# Completado: Sam  Oomen
# Empezando petición a: https://www.procyclingstats.com/rider/carlos-verona
# Petición completada con éxito!
# Completado: Carlos  Verona
# Empezando petición a: https://www.procyclingstats.com/rider/ryan-gibbons
# Petición completada con éxito!
# Completado: Ryan  Gibbons
# Empezando petición a: https://www.procyclingstats.com/rider/jonathan-milan
# Petición completada con éxito!
# Completado: Jonathan  Milan
# Empezando petición a: https://www.procyclingstats.com/rider/andrea-bagioli
# Petición completada con éxito!
# Completado: Andrea  Bagioli
# Empezando petición a: https://www.procyclingstats.com/rider/alex-kirsch
# Petición completada con éxito!
# Completado: Alex  Kirsch
# Empezando petición a: https://www.procyclingstats.com/rider/natnael-tesfatsion
# Petición completada con éxito!
# Completado: Natnael  Tesfatsion
# Empezando petición a: https://www.procyclingstats.com/rider/amanuel-ghebreigzabhier
# Petición completada con éxito!
# Completado: Amanuel  Ghebreigzabhier
# Empezando petición a: https://www.procyclingstats.com/rider/tim-declercq
# Petición completada con éxito!
# Completado: Tim  Declercq
# Empezando petición a: https://www.procyclingstats.com/rider/thibau-nys
# Petición completada con éxito!
# Completado: Thibau  Nys
# Empezando petición a: https://www.procyclingstats.com/rider/mathias-vacek
# Petición completada con éxito!
# Completado: Mathias  Vacek
# Empezando petición a: https://www.procyclingstats.com/rider/juan-pedro-lopez
# Petición completada con éxito!
# Completado: Juan Pedro  López
# Empezando petición a: https://www.procyclingstats.com/rider/julien-bernard
# Petición completada con éxito!
# Completado: Julien  Bernard
# Empezando petición a: https://www.procyclingstats.com/rider/jacopo-mosca
# Petición completada con éxito!
# Completado: Jacopo  Mosca
# Empezando petición a: https://www.procyclingstats.com/rider/quinn-simmons
# Petición completada con éxito!
# Completado: Quinn  Simmons
# Empezando petición a: https://www.procyclingstats.com/rider/daan-hoole
# Petición completada con éxito!
# Completado: Daan  Hoole
# Empezando petición a: https://www.procyclingstats.com/rider/otto-vergaerde
# Petición completada con éxito!
# Completado: Otto  Vergaerde
# Empezando petición a: https://www.procyclingstats.com/rider/nairo-quintana
# Petición completada con éxito!
# Completado: Nairo  Quintana
# Empezando petición a: https://www.procyclingstats.com/rider/enric-mas
# Petición completada con éxito!
# Completado: Enric  Mas
# Empezando petición a: https://www.procyclingstats.com/rider/fernando-gaviria
# Petición completada con éxito!
# Completado: Fernando  Gaviria
# Empezando petición a: https://www.procyclingstats.com/rider/davide-formolo
# Petición completada con éxito!
# Completado: Davide  Formolo
# Empezando petición a: https://www.procyclingstats.com/rider/alex-aranburu
# Petición completada con éxito!
# Completado: Alex  Aranburu
# Empezando petición a: https://www.procyclingstats.com/rider/nelson-oliveira
# Petición completada con éxito!
# Completado: Nelson  Oliveira
# Empezando petición a: https://www.procyclingstats.com/rider/davide-cimolai
# Petición completada con éxito!
# Completado: Davide  Cimolai
# Empezando petición a: https://www.procyclingstats.com/rider/ruben-guerreiro
# Petición completada con éxito!
# Completado: Ruben  Guerreiro
# Empezando petición a: https://www.procyclingstats.com/rider/ivan-garcia-cortina
# Petición completada con éxito!
# Completado: Iván  García Cortina
# Empezando petición a: https://www.procyclingstats.com/rider/remi-cavagna
# Petición completada con éxito!
# Completado: Rémi  Cavagna
# Empezando petición a: https://www.procyclingstats.com/rider/ivan-ramiro-sosa
# Petición completada con éxito!
# Completado: Iván Ramiro  Sosa
# Empezando petición a: https://www.procyclingstats.com/rider/gregor-muhlberger
# Petición completada con éxito!
# Completado: Gregor  Mühlberger
# Empezando petición a: https://www.procyclingstats.com/rider/einer-rubio
# Petición completada con éxito!
# Completado: Einer  Rubio
# Empezando petición a: https://www.procyclingstats.com/rider/gonzalo-serrano
# Petición completada con éxito!
# Completado: Gonzalo  Serrano
# Empezando petición a: https://www.procyclingstats.com/rider/antonio-pedrero
# Petición completada con éxito!
# Completado: Antonio  Pedrero
# Empezando petición a: https://www.procyclingstats.com/rider/oier-lazkano
# Petición completada con éxito!
# Completado: Oier  Lazkano
# Empezando petición a: https://www.procyclingstats.com/rider/william-barta
# Petición completada con éxito!
# Completado: Will  Barta
# Empezando petición a: https://www.procyclingstats.com/rider/pelayo-sanchez-mayo
# Petición completada con éxito!
# Completado: Pelayo  Sánchez
# Empezando petición a: https://www.procyclingstats.com/rider/mathias-norsgaard
# Petición completada con éxito!
# Completado: Mathias  Norsgaard
# Empezando petición a: https://www.procyclingstats.com/rider/carlos-canal
# Petición completada con éxito!
# Completado: Carlos  Canal
# Empezando petición a: https://www.procyclingstats.com/rider/javier-romo
# Petición completada con éxito!
# Completado: Javier  Romo
# Empezando petición a: https://www.procyclingstats.com/rider/jorge-arcas
# Petición completada con éxito!
# Completado: Jorge  Arcas
# Empezando petición a: https://www.procyclingstats.com/rider/albert-torres
# Petición completada con éxito!
# Completado: Albert  Torres
# Empezando petición a: https://www.procyclingstats.com/rider/sergio-samitier
# Petición completada con éxito!
# Completado: Sergio  Samitier
# Empezando petición a: https://www.procyclingstats.com/rider/jon-barrenetxea-golzarri
# Petición completada con éxito!
# Completado: Jon  Barrenetxea
# Empezando petición a: https://www.procyclingstats.com/rider/johan-jacobs
# Petición completada con éxito!
# Completado: Johan  Jacobs
# Empezando petición a: https://www.procyclingstats.com/rider/ivan-romeo
# Petición completada con éxito!
# Completado: Iván  Romeo
# Empezando petición a: https://www.procyclingstats.com/rider/lorenzo-milesi
# Petición completada con éxito!
# Completado: Lorenzo  Milesi
# Empezando petición a: https://www.procyclingstats.com/rider/vinicius-rangel-costa
# Petición completada con éxito!
# Completado: Vinícius  Rangel
# Empezando petición a: https://www.procyclingstats.com/rider/julian-alaphilippe
# Petición completada con éxito!
# Completado: Julian  Alaphilippe
# Empezando petición a: https://www.procyclingstats.com/rider/remco-evenepoel
# Petición completada con éxito!
# Completado: Remco  Evenepoel
# Empezando petición a: https://www.procyclingstats.com/rider/mikel-landa
# Petición completada con éxito!
# Completado: Mikel  Landa
# Empezando petición a: https://www.procyclingstats.com/rider/yves-lampaert
# Petición completada con éxito!
# Completado: Yves  Lampaert
# Empezando petición a: https://www.procyclingstats.com/rider/tim-merlier
# Petición completada con éxito!
# Completado: Tim  Merlier
# Empezando petición a: https://www.procyclingstats.com/rider/kasper-asgreen
# ...
# Empezando petición a: https://www.procyclingstats.com/rider/david-martin-romero
# Petición completada con éxito!
# Completado: David  Martin
# Empezando petición a: https://www.procyclingstats.com/rider/german-dario-gomez
# Petición completada con éxito!
# Completado: Germán Darío  Gómez
# Empezando petición a: https://www.procyclingstats.com/rider/javier-serrano
# Petición completada con éxito!
# Completado: Javier  Serrano
# Empezando petición a: https://www.procyclingstats.com/rider/andrea-pietrobon
# Petición completada con éxito!
# Completado: Andrea  Pietrobon
# Empezando petición a: https://www.procyclingstats.com/rider/fernando-tercero-lopez
# Petición completada con éxito!
# Completado: Fernando  Tercero
# Empezando petición a: https://www.procyclingstats.com/rider/francisco-munoz-llana
# Petición completada con éxito!
# Completado: Francisco  Muñoz
# Empezando petición a: https://www.procyclingstats.com/rider/aidan-buttigieg
# Petición completada con éxito!
# Completado: Aidan  Buttigieg
# Empezando petición a: https://www.procyclingstats.com/rider/luca-bagnara
# Petición completada con éxito!
# Completado: Luca  Bagnara
# Empezando petición a: https://www.procyclingstats.com/rider/gabriele-raccagni
# Petición completada con éxito!
# Completado: Gabriele  Raccagni
# Empezando petición a: https://www.procyclingstats.com/rider/julien-simon
# Petición completada con éxito!
# Completado: Julien  Simon
# Empezando petición a: https://www.procyclingstats.com/rider/pierre-latour
# Petición completada con éxito!
# Completado: Pierre  Latour
# Empezando petición a: https://www.procyclingstats.com/rider/alexis-vuillermoz
# Petición completada con éxito!
# Completado: Alexis  Vuillermoz
# Empezando petición a: https://www.procyclingstats.com/rider/anthony-turgis
# Petición completada con éxito!
# Completado: Anthony  Turgis
# Empezando petición a: https://www.procyclingstats.com/rider/dries-van-gestel
# Petición completada con éxito!
# Completado: Dries Van Gestel
# Empezando petición a: https://www.procyclingstats.com/rider/lorrenzo-manzin
# Petición completada con éxito!
# Completado: Lorrenzo  Manzin
# Empezando petición a: https://www.procyclingstats.com/rider/mathieu-burgaudeau
# Petición completada con éxito!
# Completado: Mathieu  Burgaudeau
# Empezando petición a: https://www.procyclingstats.com/rider/steff-cras
# Petición completada con éxito!
# Completado: Steff  Cras
# Empezando petición a: https://www.procyclingstats.com/rider/jason-tesson
# Petición completada con éxito!
# Completado: Jason  Tesson
# Empezando petición a: https://www.procyclingstats.com/rider/geoffrey-soupe
# Petición completada con éxito!
# Completado: Geoffrey  Soupe
# Empezando petición a: https://www.procyclingstats.com/rider/sandy-dujardin
# Petición completada con éxito!
# Completado: Sandy  Dujardin
# Empezando petición a: https://www.procyclingstats.com/rider/valentin-ferron
# Petición completada con éxito!
# Completado: Valentin  Ferron
# Empezando petición a: https://www.procyclingstats.com/rider/emilien-jeanniere
# Petición completada con éxito!
# Completado: Emilien  Jeannière
# Empezando petición a: https://www.procyclingstats.com/rider/jordan-jegat
# Petición completada con éxito!
# Completado: Jordan  Jegat
# Empezando petición a: https://www.procyclingstats.com/rider/fabien-doubey
# Petición completada con éxito!
# Completado: Fabien  Doubey
# Empezando petición a: https://www.procyclingstats.com/rider/fabien-grellier
# Petición completada con éxito!
# Completado: Fabien  Grellier
# Empezando petición a: https://www.procyclingstats.com/rider/paul-ourselin
# Petición completada con éxito!
# Completado: Paul  Ourselin
# Empezando petición a: https://www.procyclingstats.com/rider/thomas-gachignard
# Petición completada con éxito!
# Completado: Thomas  Gachignard
# Empezando petición a: https://www.procyclingstats.com/rider/matheo-vercher
# Petición completada con éxito!
# Completado: Mattéo  Vercher
# Empezando petición a: https://www.procyclingstats.com/rider/thomas-bonnet
# Petición completada con éxito!
# Completado: Thomas  Bonnet
# Empezando petición a: https://www.procyclingstats.com/rider/alan-jousseaume
# Petición completada con éxito!
# Completado: Alan  Jousseaume
# Empezando petición a: https://www.procyclingstats.com/rider/lucas-boniface
# Petición completada con éxito!
# Completado: Lucas  Boniface
# Empezando petición a: https://www.procyclingstats.com/rider/baptiste-vadic
# Petición completada con éxito!
# Completado: Baptiste  Vadic
# Empezando petición a: https://www.procyclingstats.com/rider/rayan-boulahoite
# Petición completada con éxito!
# Completado: Rayan  Boulahoite
# Empezando petición a: https://www.procyclingstats.com/rider/nicola-marcerou
# Petición completada con éxito!
# Completado: Nicola  Marcerou
# Empezando petición a: https://www.procyclingstats.com/rider/clement-sanchez
# Petición completada con éxito!
# Completado: Clément  Sanchez
# Empezando petición a: https://www.procyclingstats.com/rider/matteo-trentin
# Petición completada con éxito!
# Completado: Matteo  Trentin
# Empezando petición a: https://www.procyclingstats.com/rider/sebastien-reichenbach
# Petición completada con éxito!
# Completado: Sébastien  Reichenbach
# Empezando petición a: https://www.procyclingstats.com/rider/michael-storer
# Petición completada con éxito!
# Completado: Michael  Storer
# Empezando petición a: https://www.procyclingstats.com/rider/arvid-de-kleijn
# Petición completada con éxito!
# Completado: Arvid de Kleijn
# Empezando petición a: https://www.procyclingstats.com/rider/alberto-dainese
# Petición completada con éxito!
# Completado: Alberto  Dainese
# Empezando petición a: https://www.procyclingstats.com/rider/alexander-kamp
# Petición completada con éxito!
# Completado: Alexander  Kamp
# Empezando petición a: https://www.procyclingstats.com/rider/alexander-krieger
# Petición completada con éxito!
# Completado: Alexander  Krieger
# Empezando petición a: https://www.procyclingstats.com/rider/tom-bohli
# Petición completada con éxito!
# Completado: Tom  Bohli
# Empezando petición a: https://www.procyclingstats.com/rider/simon-pellaud
# Petición completada con éxito!
# Completado: Simon  Pellaud
# Empezando petición a: https://www.procyclingstats.com/rider/yannis-voisard
# Petición completada con éxito!
# Completado: Yannis  Voisard
# Empezando petición a: https://www.procyclingstats.com/rider/lucas-eriksson
# Petición completada con éxito!
# Completado: Lucas  Eriksson
# Empezando petición a: https://www.procyclingstats.com/rider/marius-mayrhofer
# Petición completada con éxito!
# Completado: Marius  Mayrhofer
# Empezando petición a: https://www.procyclingstats.com/rider/roland-thalmann
# Petición completada con éxito!
# Completado: Roland  Thalmann
# Empezando petición a: https://www.procyclingstats.com/rider/marco-brenner
# Petición completada con éxito!
# Completado: Marco  Brenner
# Empezando petición a: https://www.procyclingstats.com/rider/rick-pluimers
# Petición completada con éxito!
# Completado: Rick  Pluimers
# Empezando petición a: https://www.procyclingstats.com/rider/maikel-zijlaard
# Petición completada con éxito!
# Completado: Maikel  Zijlaard
# Empezando petición a: https://www.procyclingstats.com/rider/florian-stork
# Petición completada con éxito!
# Completado: Florian  Stork
# Empezando petición a: https://www.procyclingstats.com/rider/luc-wirtgen
# Petición completada con éxito!
# Completado: Luc  Wirtgen
# Empezando petición a: https://www.procyclingstats.com/rider/joel-suter
# Petición completada con éxito!
# Completado: Joel  Suter
# Empezando petición a: https://www.procyclingstats.com/rider/robin-froidevaux
# Petición completada con éxito!
# Completado: Robin  Froidevaux
# Empezando petición a: https://www.procyclingstats.com/rider/arthur-kluckers
# Petición completada con éxito!
# Completado: Arthur  Kluckers
# Empezando petición a: https://www.procyclingstats.com/rider/jacob-eriksson
# Petición completada con éxito!
# Completado: Jacob  Eriksson
# Empezando petición a: https://www.procyclingstats.com/rider/petr-kelemen
# Petición completada con éxito!
# Completado: Petr  Kelemen
# Empezando petición a: https://www.procyclingstats.com/rider/mika-heming
# Petición completada con éxito!
# Completado: Miká  Heming
# Empezando petición a: https://www.procyclingstats.com/rider/mathys-rondel
# Petición completada con éxito!
# Completado: Mathys  Rondel
# Empezando petición a: https://www.procyclingstats.com/rider/hannes-wilksch
# Petición completada con éxito!
# Completado: Hannes  Wilksch
# Empezando petición a: https://www.procyclingstats.com/rider/sebastian-kolze-changizi
# Petición completada con éxito!
# Completado: Sebastian  Kolze Changizi
# Empezando petición a: https://www.procyclingstats.com/rider/nils-brun
# Petición completada con éxito!
# Completado: Nils  Brun
# Empezando petición a: https://www.procyclingstats.com/rider/alois-charrin
# Petición completada con éxito!
# Completado: Aloïs  Charrin
# Empezando petición a: https://www.procyclingstats.com/rider/alexander-kristoff
# Petición completada con éxito!
# Completado: Alexander  Kristoff
# Empezando petición a: https://www.procyclingstats.com/rider/magnus-cort-nielsen
# Petición completada con éxito!
# Completado: Magnus  Cort
# Empezando petición a: https://www.procyclingstats.com/rider/odd-christian-eiking
# Petición completada con éxito!
# Completado: Odd Christian  Eiking
# Empezando petición a: https://www.procyclingstats.com/rider/rasmus-tiller
# Petición completada con éxito!
# Completado: Rasmus  Tiller
# Empezando petición a: https://www.procyclingstats.com/rider/tobias-halland-johannessen
# Petición completada con éxito!
# Completado: Tobias Halland  Johannessen
# Empezando petición a: https://www.procyclingstats.com/rider/soren-waerenskjold
# Petición completada con éxito!
# Completado: Søren  Wærenskjold
# Empezando petición a: https://www.procyclingstats.com/rider/markus-hoelgaard
# Petición completada con éxito!
# Completado: Markus  Hoelgaard
# Empezando petición a: https://www.procyclingstats.com/rider/andreas-leknessund
# Petición completada con éxito!
# Completado: Andreas  Leknessund
# Empezando petición a: https://www.procyclingstats.com/rider/jonas-abrahamsen
# Petición completada con éxito!
# Completado: Jonas  Abrahamsen
# Empezando petición a: https://www.procyclingstats.com/rider/fredrik-dversnes
# Petición completada con éxito!
# Completado: Fredrik  Dversnes
# Empezando petición a: https://www.procyclingstats.com/rider/anders-skaarseth
# Petición completada con éxito!
# Completado: Anders  Skaarseth
# Empezando petición a: https://www.procyclingstats.com/rider/niklas-larsen
# Petición completada con éxito!
# Completado: Niklas  Larsen
# Empezando petición a: https://www.procyclingstats.com/rider/rasmus-bogh-wallin
# Petición completada con éxito!
# Completado: Rasmus Bøgh  Wallin
# Empezando petición a: https://www.procyclingstats.com/rider/erlend-blikra
# Petición completada con éxito!
# Completado: Erlend  Blikra
# Empezando petición a: https://www.procyclingstats.com/rider/tord-gudmestad
# Petición completada con éxito!
# Completado: Tord  Gudmestad
# Empezando petición a: https://www.procyclingstats.com/rider/idar-andersen
# Petición completada con éxito!
# Completado: Idar  Andersen
# Empezando petición a: https://www.procyclingstats.com/rider/adne-holter
# Petición completada con éxito!
# Completado: Ådne  Holter
# Empezando petición a: https://www.procyclingstats.com/rider/erik-nordsaeter-resell
# Petición completada con éxito!
# Completado: Erik Nordsæter  Resell
# Empezando petición a: https://www.procyclingstats.com/rider/anders-halland-johannessen
# Petición completada con éxito!
# Completado: Anders Halland  Johannessen
# Empezando petición a: https://www.procyclingstats.com/rider/stian-fredheim
# Petición completada con éxito!
# Completado: Stian  Fredheim
# Empezando petición a: https://www.procyclingstats.com/rider/johannes-kulset
# Petición completada con éxito!
# Completado: Johannes  Kulset
# Empezando petición a: https://www.procyclingstats.com/rider/jonas-iversby-hvideberg
# Petición completada con éxito!
# Completado: Jonas Iversby  Hvideberg
# Empezando petición a: https://www.procyclingstats.com/rider/louis-bendixen
# Petición completada con éxito!
# Completado: Louis  Bendixen
# Empezando petición a: https://www.procyclingstats.com/rider/martin-urianstad
# Petición completada con éxito!
# Completado: Martin Urianstad Bugge
# Empezando petición a: https://www.procyclingstats.com/rider/william-blume-levy
# Petición completada con éxito!
# Completado: William  Blume Levy
# Empezando petición a: https://www.procyclingstats.com/rider/carl-frederik-bevort
# Petición completada con éxito!
# Completado: Carl-Frederik  Bévort
# Empezando petición a: https://www.procyclingstats.com/rider/sakarias-koller-loland
# Petición completada con éxito!
# Completado: Sakarias Koller  Løland
# Empezando petición a: https://www.procyclingstats.com/rider/marcus-sander-hansen
# Petición completada con éxito!
# Completado: Marcus  Sander Hansen
# Empezando petición a: https://www.procyclingstats.com/rider/sindre-kulset
# Petición completada con éxito!
# Completado: Sindre  Kulset
# Empezando petición a: https://www.procyclingstats.com/rider/domenico-pozzovivo
# Petición completada con éxito!
# Completado: Domenico  Pozzovivo
# Empezando petición a: https://www.procyclingstats.com/rider/filippo-fiorelli
# Petición completada con éxito!
# Completado: Filippo  Fiorelli
# Empezando petición a: https://www.procyclingstats.com/rider/davide-gabburo
# Petición completada con éxito!
# Completado: Davide  Gabburo
# Empezando petición a: https://www.procyclingstats.com/rider/alessandro-tonelli
# Petición completada con éxito!
# Completado: Alessandro  Tonelli
# Empezando petición a: https://www.procyclingstats.com/rider/enrico-zanoncello
# Petición completada con éxito!
# Completado: Enrico  Zanoncello
# Empezando petición a: https://www.procyclingstats.com/rider/giulio-pellizzari
# Petición completada con éxito!
# Completado: Giulio  Pellizzari
# Empezando petición a: https://www.procyclingstats.com/rider/luca-covili
# Petición completada con éxito!
# Completado: Luca  Covili
# Empezando petición a: https://www.procyclingstats.com/rider/martin-marcellusi
# Petición completada con éxito!
# Completado: Martin  Marcellusi
# Empezando petición a: https://www.procyclingstats.com/rider/luca-colnaghi
# Petición completada con éxito!
# Completado: Luca  Colnaghi
# Empezando petición a: https://www.procyclingstats.com/rider/filippo-magli2
# Petición completada con éxito!
# Completado: Filippo  Magli
# Empezando petición a: https://www.procyclingstats.com/rider/manuele-tarozzi
# Petición completada con éxito!
# Completado: Manuele  Tarozzi
# Empezando petición a: https://www.procyclingstats.com/rider/samuele-zoccarato
# Petición completada con éxito!
# Completado: Samuele  Zoccarato
# Empezando petición a: https://www.procyclingstats.com/rider/alessio-martinelli
# Petición completada con éxito!
# Completado: Alessio  Martinelli
# Empezando petición a: https://www.procyclingstats.com/rider/alessandro-pinarello
# Petición completada con éxito!
# Completado: Alessandro  Pinarello
# Empezando petición a: https://www.procyclingstats.com/rider/riccardo-lucca
# Petición completada con éxito!
# Completado: Riccardo  Lucca
# Empezando petición a: https://www.procyclingstats.com/rider/alex-tolio
# Petición completada con éxito!
# Completado: Alex  Tolio
# Empezando petición a: https://www.procyclingstats.com/rider/vicente-rojas
# Petición completada con éxito!
# Completado: Vicente  Rojas
# Empezando petición a: https://www.procyclingstats.com/rider/lorenzo-conforti
# Petición completada con éxito!
# Completado: Lorenzo  Conforti
# Empezando petición a: https://www.procyclingstats.com/rider/mattia-pinazzi
# Petición completada con éxito!
# Completado: Mattia  Pinazzi
# Empezando petición a: https://www.procyclingstats.com/rider/federico-biagini
# Petición completada con éxito!
# Completado: Federico  Biagini
# Empezando petición a: https://www.procyclingstats.com/rider/matteo-scalco
# Petición completada con éxito!
# Completado: Matteo  Scalco
# Empezando petición a: https://www.procyclingstats.com/rider/luca-paletti
# Petición completada con éxito!
# Completado: Luca  Paletti
# Empezando petición a: https://www.procyclingstats.com/rider/filippo-turconi
# Petición completada con éxito!
# Completado: Filippo  Turconi
# Información de ciclistas obtenida

# %% [markdown]
# ### Obtenemos .csv del ranking UCI

# %%
def get_ranking(year):
    '''Función para obtener el ranking de ciclistas de un año'''
    print("Obteniendo ranking de ciclistas actual")
    if year == 2023:
        date = "2023-12-26"
    elif year == 2022:
        date = "2022-12-27"
    else:
        date = str(year)+"-12-31"
    

    # Obtenemos el ranking de los 100 primeros
    url_str = "https://www.procyclingstats.com/rankings.php?date="+date+"&nation=&age=&zage=&page=smallerorequal&team=&offset=0&teamlevel=&filter=Filter&p=me&s=uci-individual"
    ranking_soup = download_soup(url_str)
    ranking = ranking_soup.find_all('tr')
    ranking_list = []
    for i in range(1, len(ranking)):
        rider = ranking[i].find_all('td')
        rider_link = rider[3].find('a')
        # Hacemos scrapping del link del ciclista para obtener el nombre
        rider_url = "https://www.procyclingstats.com/" + rider_link['href']
        rider_name = get_uniquerider_infos(rider_url)["fullname"][0]
        rider_info = [rider_name, rider[4].text, rider[5].text]
        ranking_list.append(rider_info)
    ## Creamos un DataFrame con la información
    df_ranking = pd.DataFrame(ranking_list, columns=["rider", "team", "points"])

    # Obtenemos los siguientes 100 y almacenamos en el DataFrame
    url_str = "https://www.procyclingstats.com/rankings.php?date="+date+"&nation=&age=&zage=&page=smallerorequal&team=&offset=100&teamlevel=&filter=Filter&p=me&s=uci-individual"
    ranking_soup = download_soup(url_str)
    ranking = ranking_soup.find_all('tr')
    ranking_list = []
    for i in range(1, len(ranking)):
        rider = ranking[i].find_all('td')
        rider_link = rider[3].find('a')
        # Hacemos scrapping del link del ciclista para obtener el nombre
        rider_url = "https://www.procyclingstats.com/" + rider_link['href']
        rider_name = get_uniquerider_infos(rider_url)["fullname"][0]
        rider_info = [rider_name, rider[4].text, rider[5].text]
        ranking_list.append(rider_info)
    ## Creamos un DataFrame con la información
    df_ranking2 = pd.DataFrame(ranking_list, columns=["rider", "team", "points"])



    # Obtenemos el ranking de los 100 siguientes y almacenamos en el DataFrame
    url_str = "https://www.procyclingstats.com/rankings.php?date="+date+"&nation=&age=&zage=&page=smallerorequal&team=&offset=200&teamlevel=&filter=Filter&p=me&s=uci-individual"
    ranking_soup = download_soup(url_str)
    ranking = ranking_soup.find_all('tr')
    ranking_list = []
    for i in range(1, len(ranking)):
        rider = ranking[i].find_all('td')
        rider_link = rider[3].find('a')
        # Hacemos scrapping del link del ciclista para obtener el nombre
        rider_url = "https://www.procyclingstats.com/" + rider_link['href']
        rider_name = get_uniquerider_infos(rider_url)["fullname"][0]
        rider_info = [rider_name, rider[4].text, rider[5].text]
        ranking_list.append(rider_info)
    ## Creamos un DataFrame con la información
    df_ranking3 = pd.DataFrame(ranking_list, columns=["rider", "team", "points"])

    # Obtenemos los 100 siguientes y almacenamos en el DataFrame
    url_str = "https://www.procyclingstats.com/rankings.php?date="+date+"&nation=&age=&zage=&page=smallerorequal&team=&offset=300&teamlevel=&filter=Filter&p=me&s=uci-individual"
    ranking_soup = download_soup(url_str)
    ranking = ranking_soup.find_all('tr')
    ranking_list = []
    for i in range(1, len(ranking)):
        rider = ranking[i].find_all('td')
        rider_link = rider[3].find('a')
        # Hacemos scrapping del link del ciclista para obtener el nombre
        rider_url = "https://www.procyclingstats.com/" + rider_link['href']
        rider_name = get_uniquerider_infos(rider_url)["fullname"][0]
        rider_info = [rider_name, rider[4].text, rider[5].text]
        ranking_list.append(rider_info)
    ## Creamos un DataFrame con la información
    df_ranking4 = pd.DataFrame(ranking_list, columns=["rider", "team", "points"])

    # Obtenemos el ranking de los 100 siguientes y almacenamos en el DataFrame
    url_str = "https://www.procyclingstats.com/rankings.php?date="+date+"&nation=&age=&zage=&page=smallerorequal&team=&offset=400&teamlevel=&filter=Filter&p=me&s=uci-individual"
    ranking_soup = download_soup(url_str)
    ranking = ranking_soup.find_all('tr')
    ranking_list = []
    for i in range(1, len(ranking)):
        rider = ranking[i].find_all('td')
        rider_link = rider[3].find('a')
        # Hacemos scrapping del link del ciclista para obtener el nombre
        rider_url = "https://www.procyclingstats.com/" + rider_link['href']
        rider_name = get_uniquerider_infos(rider_url)["fullname"][0]
        rider_info = [rider_name, rider[4].text, rider[5].text]
        ranking_list.append(rider_info)
    ## Creamos un DataFrame con la información
    df_ranking5 = pd.DataFrame(ranking_list, columns=["rider", "team", "points"])

    # Concatenamos los DataFrames
    df_ranking = pd.concat([df_ranking, df_ranking2, df_ranking3, df_ranking4, df_ranking5], ignore_index=True)
    df_ranking.to_csv("data/ranking_" + str(year) + ".csv")

# %%
# Obtenemos el ranking UCI de 2023
get_ranking(2024)
# Out:
# Obteniendo ranking de ciclistas actual
# Empezando petición a: https://www.procyclingstats.com/rankings.php?date=2024-12-31&nation=&age=&zage=&page=smallerorequal&team=&offset=0&teamlevel=&filter=Filter&p=me&s=uci-individual
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/rider/tadej-pogacar
# Petición completada con éxito!
# Completado: Tadej  Pogačar
# Empezando petición a: https://www.procyclingstats.com/rider/remco-evenepoel
# Petición completada con éxito!
# Completado: Remco  Evenepoel
# Empezando petición a: https://www.procyclingstats.com/rider/jasper-philipsen
# Petición completada con éxito!
# Completado: Jasper  Philipsen
# Empezando petición a: https://www.procyclingstats.com/rider/ben-o-connor
# Petición completada con éxito!
# Completado: Ben  O'Connor
# Empezando petición a: https://www.procyclingstats.com/rider/mathieu-van-der-poel
# Petición completada con éxito!
# Completado: Mathieu van der Poel
# Empezando petición a: https://www.procyclingstats.com/rider/marc-hirschi
# Petición completada con éxito!
# Completado: Marc  Hirschi
# Empezando petición a: https://www.procyclingstats.com/rider/jonas-vingegaard
# Petición completada con éxito!
# Completado: Jonas  Vingegaard
# Empezando petición a: https://www.procyclingstats.com/rider/primoz-roglic
# Petición completada con éxito!
# Completado: Primož  Roglič
# Empezando petición a: https://www.procyclingstats.com/rider/biniam-girmay
# Petición completada con éxito!
# Completado: Biniam  Girmay
# Empezando petición a: https://www.procyclingstats.com/rider/wout-van-aert
# Petición completada con éxito!
# Completado: Wout van Aert
# Empezando petición a: https://www.procyclingstats.com/rider/enric-mas
# Petición completada con éxito!
# Completado: Enric  Mas
# Empezando petición a: https://www.procyclingstats.com/rider/mads-pedersen
# Petición completada con éxito!
# Completado: Mads  Pedersen
# Empezando petición a: https://www.procyclingstats.com/rider/matteo-jorgenson
# Petición completada con éxito!
# Completado: Matteo  Jorgenson
# Empezando petición a: https://www.procyclingstats.com/rider/maxim-van-gils
# Petición completada con éxito!
# Completado: Maxim Van Gils
# Empezando petición a: https://www.procyclingstats.com/rider/arnaud-de-lie
# Petición completada con éxito!
# Completado: Arnaud De Lie
# Empezando petición a: https://www.procyclingstats.com/rider/tim-merlier
# Petición completada con éxito!
# Completado: Tim  Merlier
# Empezando petición a: https://www.procyclingstats.com/rider/jonathan-milan
# Petición completada con éxito!
# Completado: Jonathan  Milan
# Empezando petición a: https://www.procyclingstats.com/rider/mattias-skjelmose-jensen
# Petición completada con éxito!
# Completado: Mattias  Skjelmose
# Empezando petición a: https://www.procyclingstats.com/rider/carlos-rodriguez-cano
# Petición completada con éxito!
# Completado: Carlos  Rodríguez
# Empezando petición a: https://www.procyclingstats.com/rider/richard-carapaz
# Petición completada con éxito!
# Completado: Richard  Carapaz
# Empezando petición a: https://www.procyclingstats.com/rider/brandon-mcnulty
# Petición completada con éxito!
# Completado: Brandon  McNulty
# Empezando petición a: https://www.procyclingstats.com/rider/adam-yates
# Petición completada con éxito!
# Completado: Adam  Yates
# Empezando petición a: https://www.procyclingstats.com/rider/mikel-landa
# Petición completada con éxito!
# Completado: Mikel  Landa
# Empezando petición a: https://www.procyclingstats.com/rider/juan-ayuso-pesquera
# Petición completada con éxito!
# Completado: Juan  Ayuso
# Empezando petición a: https://www.procyclingstats.com/rider/joao-almeida
# Petición completada con éxito!
# Completado: João  Almeida
# Empezando petición a: https://www.procyclingstats.com/rider/aleksandr-vlasov
# Petición completada con éxito!
# Completado: Aleksandr  Vlasov
# Empezando petición a: https://www.procyclingstats.com/rider/toms-skujins
# Petición completada con éxito!
# Completado: Toms  Skujiņš
# Empezando petición a: https://www.procyclingstats.com/rider/stefan-kung
# Petición completada con éxito!
# Completado: Stefan  Küng
# Empezando petición a: https://www.procyclingstats.com/rider/thomas-pidcock
# Petición completada con éxito!
# Completado: Thomas  Pidcock
# Empezando petición a: https://www.procyclingstats.com/rider/michael-matthews
# Petición completada con éxito!
# Completado: Michael  Matthews
# Empezando petición a: https://www.procyclingstats.com/rider/romain-bardet
# Petición completada con éxito!
# Completado: Romain  Bardet
# Empezando petición a: https://www.procyclingstats.com/rider/olav-kooij
# Petición completada con éxito!
# Completado: Olav  Kooij
# Empezando petición a: https://www.procyclingstats.com/rider/jhonatan-narvaez
# Petición completada con éxito!
# Completado: Jhonatan  Narváez
# Empezando petición a: https://www.procyclingstats.com/rider/daniel-felipe-martinez
# Petición completada con éxito!
# Completado: Daniel Felipe  Martínez
# Empezando petición a: https://www.procyclingstats.com/rider/lennert-van-eetvelt
# Petición completada con éxito!
# Completado: Lennert Van Eetvelt
# Empezando petición a: https://www.procyclingstats.com/rider/kaden-groves
# Petición completada con éxito!
# Completado: Kaden  Groves
# Empezando petición a: https://www.procyclingstats.com/rider/julian-alaphilippe
# Petición completada con éxito!
# Completado: Julian  Alaphilippe
# Empezando petición a: https://www.procyclingstats.com/rider/antonio-tiberi
# Petición completada con éxito!
# Completado: Antonio  Tiberi
# Empezando petición a: https://www.procyclingstats.com/rider/corbin-strong
# Petición completada con éxito!
# Completado: Corbin  Strong
# Empezando petición a: https://www.procyclingstats.com/rider/benoit-cosnefroy
# Petición completada con éxito!
# Completado: Benoît  Cosnefroy
# Empezando petición a: https://www.procyclingstats.com/rider/tim-wellens
# Petición completada con éxito!
# Completado: Tim  Wellens
# Empezando petición a: https://www.procyclingstats.com/rider/valentin-madouas
# Petición completada con éxito!
# Completado: Valentin  Madouas
# Empezando petición a: https://www.procyclingstats.com/rider/alberto-bettiol
# Petición completada con éxito!
# Completado: Alberto  Bettiol
# Empezando petición a: https://www.procyclingstats.com/rider/nils-politt
# Petición completada con éxito!
# Completado: Nils  Politt
# Empezando petición a: https://www.procyclingstats.com/rider/christophe-laporte
# Petición completada con éxito!
# Completado: Christophe  Laporte
# Empezando petición a: https://www.procyclingstats.com/rider/stephen-williams
# Petición completada con éxito!
# Completado: Stephen  Williams
# Empezando petición a: https://www.procyclingstats.com/rider/pello-bilbao
# Petición completada con éxito!
# Completado: Pello  Bilbao
# Empezando petición a: https://www.procyclingstats.com/rider/alex-aranburu
# Petición completada con éxito!
# Completado: Alex  Aranburu
# Empezando petición a: https://www.procyclingstats.com/rider/diego-ulissi
# Petición completada con éxito!
# Completado: Diego  Ulissi
# Empezando petición a: https://www.procyclingstats.com/rider/alexander-kristoff
# Petición completada con éxito!
# Completado: Alexander  Kristoff
# Empezando petición a: https://www.procyclingstats.com/rider/dylan-groenewegen
# Petición completada con éxito!
# Completado: Dylan  Groenewegen
# Empezando petición a: https://www.procyclingstats.com/rider/david-gaudu
# Petición completada con éxito!
# Completado: David  Gaudu
# Empezando petición a: https://www.procyclingstats.com/rider/oscar-onley
# Petición completada con éxito!
# Completado: Oscar  Onley
# Empezando petición a: https://www.procyclingstats.com/rider/romain-gregoire1
# Petición completada con éxito!
# Completado: Romain  Grégoire
# Empezando petición a: https://www.procyclingstats.com/rider/axel-zingle
# Petición completada con éxito!
# Completado: Axel  Zingle
# Empezando petición a: https://www.procyclingstats.com/rider/florian-lipowitz
# Petición completada con éxito!
# Completado: Florian  Lipowitz
# Empezando petición a: https://www.procyclingstats.com/rider/isaac-del-toro
# Petición completada con éxito!
# Completado: Isaac del Toro
# Empezando petición a: https://www.procyclingstats.com/rider/jordi-meeus
# Petición completada con éxito!
# Completado: Jordi  Meeus
# Empezando petición a: https://www.procyclingstats.com/rider/geraint-thomas
# Petición completada con éxito!
# Completado: Geraint  Thomas
# Empezando petición a: https://www.procyclingstats.com/rider/laurence-pithie
# Petición completada con éxito!
# Completado: Laurence  Pithie
# Empezando petición a: https://www.procyclingstats.com/rider/giulio-ciccone
# Petición completada con éxito!
# Completado: Giulio  Ciccone
# Empezando petición a: https://www.procyclingstats.com/rider/lenny-martinez
# Petición completada con éxito!
# Completado: Lenny  Martinez
# Empezando petición a: https://www.procyclingstats.com/rider/egan-bernal
# Petición completada con éxito!
# Completado: Egan  Bernal
# Empezando petición a: https://www.procyclingstats.com/rider/magnus-cort-nielsen
# Petición completada con éxito!
# Completado: Magnus  Cort
# Empezando petición a: https://www.procyclingstats.com/rider/tiesj-benoot
# Petición completada con éxito!
# Completado: Tiesj  Benoot
# Empezando petición a: https://www.procyclingstats.com/rider/luca-mozzato
# Petición completada con éxito!
# Completado: Luca  Mozzato
# Empezando petición a: https://www.procyclingstats.com/rider/filippo-ganna
# Petición completada con éxito!
# Completado: Filippo  Ganna
# Empezando petición a: https://www.procyclingstats.com/rider/mathias-vacek
# Petición completada con éxito!
# Completado: Mathias  Vacek
# Empezando petición a: https://www.procyclingstats.com/rider/derek-gee
# Petición completada con éxito!
# Completado: Derek  Gee
# Empezando petición a: https://www.procyclingstats.com/rider/neilson-powless
# Petición completada con éxito!
# Completado: Neilson  Powless
# Empezando petición a: https://www.procyclingstats.com/rider/roger-adria
# Petición completada con éxito!
# Completado: Roger  Adrià
# Empezando petición a: https://www.procyclingstats.com/rider/thymen-arensman
# Petición completada con éxito!
# Completado: Thymen  Arensman
# Empezando petición a: https://www.procyclingstats.com/rider/matej-mohoric
# Petición completada con éxito!
# Completado: Matej  Mohorič
# Empezando petición a: https://www.procyclingstats.com/rider/ion-izagirre
# Petición completada con éxito!
# Completado: Ion  Izagirre
# Empezando petición a: https://www.procyclingstats.com/rider/santiago-buitrago-sanchez
# Petición completada con éxito!
# Completado: Santiago  Buitrago
# Empezando petición a: https://www.procyclingstats.com/rider/max-poole
# Petición completada con éxito!
# Completado: Max  Poole
# Empezando petición a: https://www.procyclingstats.com/rider/jonas-abrahamsen
# Petición completada con éxito!
# Completado: Jonas  Abrahamsen
# Empezando petición a: https://www.procyclingstats.com/rider/pavel-sivakov
# Petición completada con éxito!
# Completado: Pavel  Sivakov
# Empezando petición a: https://www.procyclingstats.com/rider/kevin-vauquelin
# Petición completada con éxito!
# Completado: Kévin  Vauquelin
# Empezando petición a: https://www.procyclingstats.com/rider/paul-lapeira
# Petición completada con éxito!
# Completado: Paul  Lapeira
# Empezando petición a: https://www.procyclingstats.com/rider/matteo-trentin
# Petición completada con éxito!
# Completado: Matteo  Trentin
# Empezando petición a: https://www.procyclingstats.com/rider/kevin-vermaerke
# Petición completada con éxito!
# Completado: Kevin  Vermaerke
# Empezando petición a: https://www.procyclingstats.com/rider/emilien-jeanniere
# Petición completada con éxito!
# Completado: Emilien  Jeannière
# Empezando petición a: https://www.procyclingstats.com/rider/mauri-vansevenant
# Petición completada con éxito!
# Completado: Mauri  Vansevenant
# Empezando petición a: https://www.procyclingstats.com/rider/attila-valter
# Petición completada con éxito!
# Completado: Attila  Valter
# Empezando petición a: https://www.procyclingstats.com/rider/soren-waerenskjold
# Petición completada con éxito!
# Completado: Søren  Wærenskjold
# Empezando petición a: https://www.procyclingstats.com/rider/magnus-sheffield
# Petición completada con éxito!
# Completado: Magnus  Sheffield
# Empezando petición a: https://www.procyclingstats.com/rider/simon-yates
# Petición completada con éxito!
# Completado: Simon  Yates
# Empezando petición a: https://www.procyclingstats.com/rider/gerben-thijssen
# Petición completada con éxito!
# Completado: Gerben  Thijssen
# Empezando petición a: https://www.procyclingstats.com/rider/ilan-van-wilder
# Petición completada con éxito!
# Completado: Ilan Van Wilder
# Empezando petición a: https://www.procyclingstats.com/rider/joseph-blackmore
# Petición completada con éxito!
# Completado: Joseph  Blackmore
# Empezando petición a: https://www.procyclingstats.com/rider/marc-soler
# Petición completada con éxito!
# Completado: Marc  Soler
# Empezando petición a: https://www.procyclingstats.com/rider/ben-healy
# Petición completada con éxito!
# Completado: Ben  Healy
# Empezando petición a: https://www.procyclingstats.com/rider/michael-storer
# Petición completada con éxito!
# Completado: Michael  Storer
# Empezando petición a: https://www.procyclingstats.com/rider/jan-tratnik
# Petición completada con éxito!
# Completado: Jan  Tratnik
# Empezando petición a: https://www.procyclingstats.com/rider/alex-baudin
# Petición completada con éxito!
# Completado: Alex  Baudin
# Empezando petición a: https://www.procyclingstats.com/rider/alec-segaert
# Petición completada con éxito!
# Completado: Alec  Segaert
# Empezando petición a: https://www.procyclingstats.com/rider/vincenzo-albanese
# Petición completada con éxito!
# Completado: Vincenzo  Albanese
# Empezando petición a: https://www.procyclingstats.com/rider/pascal-ackermann
# Petición completada con éxito!
# Completado: Pascal  Ackermann
# Empezando petición a: https://www.procyclingstats.com/rider/jasper-stuyven
# Petición completada con éxito!
# Completado: Jasper  Stuyven
# Empezando petición a: https://www.procyclingstats.com/rankings.php?date=2024-12-31&nation=&age=&zage=&page=smallerorequal&team=&offset=100&teamlevel=&filter=Filter&p=me&s=uci-individual
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/rider/jan-christen
# Petición completada con éxito!
# Completado: Jan  Christen
# Empezando petición a: https://www.procyclingstats.com/rider/phil-bauhaus
# Petición completada con éxito!
# Completado: Phil  Bauhaus
# Empezando petición a: https://www.procyclingstats.com/rider/wilco-kelderman
# Petición completada con éxito!
# Completado: Wilco  Kelderman
# Empezando petición a: https://www.procyclingstats.com/rider/aurelien-paret-peintre
# Petición completada con éxito!
# Completado: Aurélien  Paret-Peintre
# Empezando petición a: https://www.procyclingstats.com/rider/jai-hindley
# Petición completada con éxito!
# Completado: Jai  Hindley
# Empezando petición a: https://www.procyclingstats.com/rider/jenno-berckmoes
# Petición completada con éxito!
# Completado: Jenno  Berckmoes
# Empezando petición a: https://www.procyclingstats.com/rider/marijn-van-den-berg
# Petición completada con éxito!
# Completado: Marijn van den Berg
# Empezando petición a: https://www.procyclingstats.com/rider/milan-fretin
# Petición completada con éxito!
# Completado: Milan  Fretin
# Empezando petición a: https://www.procyclingstats.com/rider/orluis-aular
# Petición completada con éxito!
# Completado: Orluis  Aular
# Empezando petición a: https://www.procyclingstats.com/rider/felix-gall
# Petición completada con éxito!
# Completado: Felix  Gall
# Empezando petición a: https://www.procyclingstats.com/rider/mikkel-bjerg
# Petición completada con éxito!
# Completado: Mikkel  Bjerg
# Empezando petición a: https://www.procyclingstats.com/rider/thibau-nys
# Petición completada con éxito!
# Completado: Thibau  Nys
# Empezando petición a: https://www.procyclingstats.com/rider/edoardo-zambanini
# Petición completada con éxito!
# Completado: Edoardo  Zambanini
# Empezando petición a: https://www.procyclingstats.com/rider/tobias-halland-johannessen
# Petición completada con éxito!
# Completado: Tobias Halland  Johannessen
# Empezando petición a: https://www.procyclingstats.com/rider/michael-woods
# Petición completada con éxito!
# Completado: Michael  Woods
# Empezando petición a: https://www.procyclingstats.com/rider/mauro-schmid
# Petición completada con éxito!
# Completado: Mauro  Schmid
# Empezando petición a: https://www.procyclingstats.com/rider/aaron-gate
# Petición completada con éxito!
# Completado: Aaron  Gate
# Empezando petición a: https://www.procyclingstats.com/rider/jay-vine
# Petición completada con éxito!
# Completado: Jay  Vine
# Empezando petición a: https://www.procyclingstats.com/rider/guillaume-martin
# Petición completada con éxito!
# Completado: Guillaume  Martin
# Empezando petición a: https://www.procyclingstats.com/rider/giulio-pellizzari
# Petición completada con éxito!
# Completado: Giulio  Pellizzari
# Empezando petición a: https://www.procyclingstats.com/rider/bryan-coquard
# Petición completada con éxito!
# Completado: Bryan  Coquard
# Empezando petición a: https://www.procyclingstats.com/rider/einer-rubio
# Petición completada con éxito!
# Completado: Einer  Rubio
# Empezando petición a: https://www.procyclingstats.com/rider/filippo-zana
# Petición completada con éxito!
# Completado: Filippo  Zana
# Empezando petición a: https://www.procyclingstats.com/rider/jefferson-cepeda-hernandez
# Petición completada con éxito!
# Completado: Jefferson Alveiro  Cepeda
# Empezando petición a: https://www.procyclingstats.com/rider/bauke-mollema
# Petición completada con éxito!
# Completado: Bauke  Mollema
# Empezando petición a: https://www.procyclingstats.com/rider/pablo-castrillo-zapater
# Petición completada con éxito!
# Completado: Pablo  Castrillo
# Empezando petición a: https://www.procyclingstats.com/rider/quentin-pacher
# Petición completada con éxito!
# Completado: Quentin  Pacher
# Empezando petición a: https://www.procyclingstats.com/rider/jenthe-biermans
# Petición completada con éxito!
# Completado: Jenthe  Biermans
# Empezando petición a: https://www.procyclingstats.com/rider/antonio-morgado
# Petición completada con éxito!
# Completado: António  Morgado
# Empezando petición a: https://www.procyclingstats.com/rider/pavel-bittner
# Petición completada con éxito!
# Completado: Pavel  Bittner
# Empezando petición a: https://www.procyclingstats.com/rider/sam-bennett
# Petición completada con éxito!
# Completado: Sam  Bennett
# Empezando petición a: https://www.procyclingstats.com/rider/maximilian-schachmann
# Petición completada con éxito!
# Completado: Maximilian  Schachmann
# Empezando petición a: https://www.procyclingstats.com/rider/arvid-de-kleijn
# Petición completada con éxito!
# Completado: Arvid de Kleijn
# Empezando petición a: https://www.procyclingstats.com/rider/danny-van-poppel
# Petición completada con éxito!
# Completado: Danny van Poppel
# Empezando petición a: https://www.procyclingstats.com/rider/fernando-gaviria
# Petición completada con éxito!
# Completado: Fernando  Gaviria
# Empezando petición a: https://www.procyclingstats.com/rider/madis-mihkels
# Petición completada con éxito!
# Completado: Madis  Mihkels
# Empezando petición a: https://www.procyclingstats.com/rider/quinten-hermans
# Petición completada con éxito!
# Completado: Quinten  Hermans
# Empezando petición a: https://www.procyclingstats.com/rider/clement-venturini
# Petición completada con éxito!
# Completado: Clément  Venturini
# Empezando petición a: https://www.procyclingstats.com/rider/valentin-paret-peintre
# Petición completada con éxito!
# Completado: Valentin  Paret-Peintre
# Empezando petición a: https://www.procyclingstats.com/rider/edward-irl-dunbar
# Petición completada con éxito!
# Completado: Eddie  Dunbar
# Empezando petición a: https://www.procyclingstats.com/rider/dorian-godon
# Petición completada con éxito!
# Completado: Dorian  Godon
# Empezando petición a: https://www.procyclingstats.com/rider/oier-lazkano
# Petición completada con éxito!
# Completado: Oier  Lazkano
# Empezando petición a: https://www.procyclingstats.com/rider/bart-lemmen
# Petición completada con éxito!
# Completado: Bart  Lemmen
# Empezando petición a: https://www.procyclingstats.com/rider/oliver-naesen
# Petición completada con éxito!
# Completado: Oliver  Naesen
# Empezando petición a: https://www.procyclingstats.com/rider/luke-plapp
# Petición completada con éxito!
# Completado: Luke  Plapp
# Empezando petición a: https://www.procyclingstats.com/rider/pau-miquel-delgado
# Petición completada con éxito!
# Completado: Pau  Miquel
# Empezando petición a: https://www.procyclingstats.com/rider/clement-champoussin
# Petición completada con éxito!
# Completado: Clément  Champoussin
# Empezando petición a: https://www.procyclingstats.com/rider/gianni-vermeersch
# Petición completada con éxito!
# Completado: Gianni  Vermeersch
# Empezando petición a: https://www.procyclingstats.com/rider/joshua-tarling
# Petición completada con éxito!
# Completado: Joshua  Tarling
# Empezando petición a: https://www.procyclingstats.com/rider/guillermo-thomas-silva-coussan
# Petición completada con éxito!
# Completado: Guillermo Thomas  Silva
# Empezando petición a: https://www.procyclingstats.com/rider/jelte-krijnsen
# Petición completada con éxito!
# Completado: Jelte  Krijnsen
# Empezando petición a: https://www.procyclingstats.com/rider/mike-teunissen
# Petición completada con éxito!
# Completado: Mike  Teunissen
# Empezando petición a: https://www.procyclingstats.com/rider/per-strand-hagenes
# Petición completada con éxito!
# Completado: Per Strand  Hagenes
# Empezando petición a: https://www.procyclingstats.com/rider/lorenzo-fortunato
# Petición completada con éxito!
# Completado: Lorenzo  Fortunato
# Empezando petición a: https://www.procyclingstats.com/rider/alexandre-delettre
# Petición completada con éxito!
# Completado: Alexandre  Delettre
# Empezando petición a: https://www.procyclingstats.com/rider/simone-velasco
# Petición completada con éxito!
# Completado: Simone  Velasco
# Empezando petición a: https://www.procyclingstats.com/rider/paul-magnier
# Petición completada con éxito!
# Completado: Paul  Magnier
# Empezando petición a: https://www.procyclingstats.com/rider/luke-lamperti
# Petición completada con éxito!
# Completado: Luke  Lamperti
# Empezando petición a: https://www.procyclingstats.com/rider/tom-van-asbroeck
# Petición completada con éxito!
# Completado: Tom Van Asbroeck
# Empezando petición a: https://www.procyclingstats.com/rider/pelayo-sanchez-mayo
# Petición completada con éxito!
# Completado: Pelayo  Sánchez
# Empezando petición a: https://www.procyclingstats.com/rider/davide-piganzoli
# Petición completada con éxito!
# Completado: Davide  Piganzoli
# Empezando petición a: https://www.procyclingstats.com/rider/lorenzo-rota
# Petición completada con éxito!
# Completado: Lorenzo  Rota
# Empezando petición a: https://www.procyclingstats.com/rider/stanislaw-aniolkowski
# Petición completada con éxito!
# Completado: Stanisław  Aniołkowski
# Empezando petición a: https://www.procyclingstats.com/rider/laurens-de-plus
# Petición completada con éxito!
# Completado: Laurens De Plus
# Empezando petición a: https://www.procyclingstats.com/rider/georg-steinhauser
# Petición completada con éxito!
# Completado: Georg  Steinhauser
# Empezando petición a: https://www.procyclingstats.com/rider/andrea-vendrame
# Petición completada con éxito!
# Completado: Andrea  Vendrame
# Empezando petición a: https://www.procyclingstats.com/rider/pierre-gautherat
# Petición completada con éxito!
# Completado: Pierre  Gautherat
# Empezando petición a: https://www.procyclingstats.com/rider/sepp-kuss
# Petición completada con éxito!
# Completado: Sepp  Kuss
# Empezando petición a: https://www.procyclingstats.com/rider/finn-fisher-black
# Petición completada con éxito!
# Completado: Finn  Fisher-Black
# Empezando petición a: https://www.procyclingstats.com/rider/archie-ryan
# Petición completada con éxito!
# Completado: Archie  Ryan
# Empezando petición a: https://www.procyclingstats.com/rider/markus-hoelgaard
# Petición completada con éxito!
# Completado: Markus  Hoelgaard
# Empezando petición a: https://www.procyclingstats.com/rider/dylan-teuns
# Petición completada con éxito!
# Completado: Dylan  Teuns
# Empezando petición a: https://www.procyclingstats.com/rider/edoardo-affini
# Petición completada con éxito!
# Completado: Edoardo  Affini
# Empezando petición a: https://www.procyclingstats.com/rider/xandro-meurisse
# Petición completada con éxito!
# Completado: Xandro  Meurisse
# Empezando petición a: https://www.procyclingstats.com/rider/lionel-taminiaux
# Petición completada con éxito!
# Completado: Lionel  Taminiaux
# Empezando petición a: https://www.procyclingstats.com/rider/victor-campenaerts
# Petición completada con éxito!
# Completado: Victor  Campenaerts
# Empezando petición a: https://www.procyclingstats.com/rider/rudy-molard
# Petición completada con éxito!
# Completado: Rudy  Molard
# Empezando petición a: https://www.procyclingstats.com/rider/filippo-baroncini
# Petición completada con éxito!
# Completado: Filippo  Baroncini
# Empezando petición a: https://www.procyclingstats.com/rider/cristian-rodriguez
# Petición completada con éxito!
# Completado: Cristián  Rodríguez
# Empezando petición a: https://www.procyclingstats.com/rider/henok-mulubrhan
# Petición completada con éxito!
# Completado: Henok  Mulubrhan
# Empezando petición a: https://www.procyclingstats.com/rider/jordan-jegat
# Petición completada con éxito!
# Completado: Jordan  Jegat
# Empezando petición a: https://www.procyclingstats.com/rider/georg-zimmermann
# Petición completada con éxito!
# Completado: Georg  Zimmermann
# Empezando petición a: https://www.procyclingstats.com/rider/alexandre-mayer
# Petición completada con éxito!
# Completado: Alexandre  Mayer
# Empezando petición a: https://www.procyclingstats.com/rider/giovanni-aleotti
# Petición completada con éxito!
# Completado: Giovanni  Aleotti
# Empezando petición a: https://www.procyclingstats.com/rider/matthew-riccitello
# Petición completada con éxito!
# Completado: Matthew  Riccitello
# Empezando petición a: https://www.procyclingstats.com/rider/jan-hirt
# Petición completada con éxito!
# Completado: Jan  Hirt
# Empezando petición a: https://www.procyclingstats.com/rider/aleksey-lutsenko
# Petición completada con éxito!
# Completado: Alexey  Lutsenko
# Empezando petición a: https://www.procyclingstats.com/rider/merhawi-kudus
# Petición completada con éxito!
# Completado: Merhawi  Kudus
# Empezando petición a: https://www.procyclingstats.com/rider/paul-penhoet
# Petición completada con éxito!
# Completado: Paul  Penhoët
# Empezando petición a: https://www.procyclingstats.com/rider/stefan-bissegger
# Petición completada con éxito!
# Completado: Stefan  Bissegger
# Empezando petición a: https://www.procyclingstats.com/rider/fabio-christen
# Petición completada con éxito!
# Completado: Fabio  Christen
# Empezando petición a: https://www.procyclingstats.com/rider/fredrik-dversnes
# Petición completada con éxito!
# Completado: Fredrik  Dversnes
# Empezando petición a: https://www.procyclingstats.com/rider/marcin-budzinski
# Petición completada con éxito!
# Completado: Marcin  Budziński
# Empezando petición a: https://www.procyclingstats.com/rider/frank-van-den-broek
# Petición completada con éxito!
# Completado: Frank van den Broek
# Empezando petición a: https://www.procyclingstats.com/rider/natnael-tesfatsion
# Petición completada con éxito!
# Completado: Natnael  Tesfatsion
# Empezando petición a: https://www.procyclingstats.com/rider/christian-scaroni
# Petición completada con éxito!
# Completado: Christian  Scaroni
# Empezando petición a: https://www.procyclingstats.com/rider/anders-foldager
# Petición completada con éxito!
# Completado: Anders  Foldager
# Empezando petición a: https://www.procyclingstats.com/rider/laurenz-rex
# Petición completada con éxito!
# Completado: Laurenz  Rex
# Empezando petición a: https://www.procyclingstats.com/rider/jason-tesson
# Petición completada con éxito!
# Completado: Jason  Tesson
# Empezando petición a: https://www.procyclingstats.com/rider/davide-de-pretto
# Petición completada con éxito!
# Completado: Davide De Pretto
# Empezando petición a: https://www.procyclingstats.com/rankings.php?date=2024-12-31&nation=&age=&zage=&page=smallerorequal&team=&offset=200&teamlevel=&filter=Filter&p=me&s=uci-individual
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/rider/wout-poels
# Petición completada con éxito!
# Completado: Wout  Poels
# Empezando petición a: https://www.procyclingstats.com/rider/arnaud-demare
# Petición completada con éxito!
# Completado: Arnaud  Démare
# Empezando petición a: https://www.procyclingstats.com/rider/clement-berthet
# Petición completada con éxito!
# Completado: Clément  Berthet
# Empezando petición a: https://www.procyclingstats.com/rider/riley-sheehan
# Petición completada con éxito!
# Completado: Riley  Sheehan
# Empezando petición a: https://www.procyclingstats.com/rider/marco-brenner
# Petición completada con éxito!
# Completado: Marco  Brenner
# Empezando petición a: https://www.procyclingstats.com/rider/urko-berrade-fernandez
# Petición completada con éxito!
# Completado: Urko  Berrade
# Empezando petición a: https://www.procyclingstats.com/rider/george-bennett
# Petición completada con éxito!
# Completado: George  Bennett
# Empezando petición a: https://www.procyclingstats.com/rider/axel-laurance
# Petición completada con éxito!
# Completado: Axel  Laurance
# Empezando petición a: https://www.procyclingstats.com/rider/juan-sebastian-molano
# Petición completada con éxito!
# Completado: Juan Sebastián  Molano
# Empezando petición a: https://www.procyclingstats.com/rider/lukas-nerurkar
# Petición completada con éxito!
# Completado: Lukas  Nerurkar
# Empezando petición a: https://www.procyclingstats.com/rider/felix-grossschartner
# Petición completada con éxito!
# Completado: Felix  Großschartner
# Empezando petición a: https://www.procyclingstats.com/rider/wilmar-paredes
# Petición completada con éxito!
# Completado: Wilmar  Paredes
# Empezando petición a: https://www.procyclingstats.com/rider/sergio-higuita
# Petición completada con éxito!
# Completado: Sergio  Higuita
# Empezando petición a: https://www.procyclingstats.com/rider/vito-braet
# Petición completada con éxito!
# Completado: Vito  Braet
# Empezando petición a: https://www.procyclingstats.com/rider/niklas-behrens
# Petición completada con éxito!
# Completado: Niklas  Behrens
# Empezando petición a: https://www.procyclingstats.com/rider/michael-valgren-andersen
# Petición completada con éxito!
# Completado: Michael  Valgren
# Empezando petición a: https://www.procyclingstats.com/rider/alberto-dainese
# Petición completada con éxito!
# Completado: Alberto  Dainese
# Empezando petición a: https://www.procyclingstats.com/rider/max-walscheid
# Petición completada con éxito!
# Completado: Max  Walscheid
# Empezando petición a: https://www.procyclingstats.com/rider/harold-tejada
# Petición completada con éxito!
# Completado: Harold  Tejada
# Empezando petición a: https://www.procyclingstats.com/rider/marco-haller
# Petición completada con éxito!
# Completado: Marco  Haller
# Empezando petición a: https://www.procyclingstats.com/rider/anthony-turgis
# Petición completada con éxito!
# Completado: Anthony  Turgis
# Empezando petición a: https://www.procyclingstats.com/rider/amaury-capiot
# Petición completada con éxito!
# Completado: Amaury  Capiot
# Empezando petición a: https://www.procyclingstats.com/rider/hugo-hofstetter
# Petición completada con éxito!
# Completado: Hugo  Hofstetter
# Empezando petición a: https://www.procyclingstats.com/rider/alfred-wright
# Petición completada con éxito!
# Completado: Fred  Wright
# Empezando petición a: https://www.procyclingstats.com/rider/tobias-lund-andresen
# Petición completada con éxito!
# Completado: Tobias Lund  Andresen
# Empezando petición a: https://www.procyclingstats.com/rider/caleb-ewan
# Petición completada con éxito!
# Completado: Caleb  Ewan
# Empezando petición a: https://www.procyclingstats.com/rider/kasper-asgreen
# Petición completada con éxito!
# Completado: Kasper  Asgreen
# Empezando petición a: https://www.procyclingstats.com/rider/tim-torn-teutenberg
# Petición completada con éxito!
# Completado: Tim Torn  Teutenberg
# Empezando petición a: https://www.procyclingstats.com/rider/warren-barguil
# Petición completada con éxito!
# Completado: Warren  Barguil
# Empezando petición a: https://www.procyclingstats.com/rider/milan-menten
# Petición completada con éxito!
# Completado: Milan  Menten
# Empezando petición a: https://www.procyclingstats.com/rider/casper-van-uden
# Petición completada con éxito!
# Completado: Casper van Uden
# Empezando petición a: https://www.procyclingstats.com/rider/simon-dehairs
# Petición completada con éxito!
# Completado: Simon  Dehairs
# Empezando petición a: https://www.procyclingstats.com/rider/max-kanter
# Petición completada con éxito!
# Completado: Max  Kanter
# Empezando petición a: https://www.procyclingstats.com/rider/rasmus-tiller
# Petición completada con éxito!
# Completado: Rasmus  Tiller
# Empezando petición a: https://www.procyclingstats.com/rider/matteo-moschetti
# Petición completada con éxito!
# Completado: Matteo  Moschetti
# Empezando petición a: https://www.procyclingstats.com/rider/lukas-kubis
# Petición completada con éxito!
# Completado: Lukáš  Kubiš
# Empezando petición a: https://www.procyclingstats.com/rider/azzedine-lagab
# Petición completada con éxito!
# Completado: Azzedine  Lagab
# Empezando petición a: https://www.procyclingstats.com/rider/pier-andre-cote
# Petición completada con éxito!
# Completado: Pier-André  Côté
# Empezando petición a: https://www.procyclingstats.com/rider/carlos-canal
# Petición completada con éxito!
# Completado: Carlos  Canal
# Empezando petición a: https://www.procyclingstats.com/rider/charles-kagimu
# Petición completada con éxito!
# Completado: Charles  Kagimu
# Empezando petición a: https://www.procyclingstats.com/rider/simone-consonni
# Petición completada con éxito!
# Completado: Simone  Consonni
# Empezando petición a: https://www.procyclingstats.com/rider/chris-harper
# Petición completada con éxito!
# Completado: Chris  Harper
# Empezando petición a: https://www.procyclingstats.com/rider/francesco-busatto
# Petición completada con éxito!
# Completado: Francesco  Busatto
# Empezando petición a: https://www.procyclingstats.com/rider/javier-romo
# Petición completada con éxito!
# Completado: Javier  Romo
# Empezando petición a: https://www.procyclingstats.com/rider/fabio-jakobsen
# Petición completada con éxito!
# Completado: Fabio  Jakobsen
# Empezando petición a: https://www.procyclingstats.com/rider/bruno-armirail
# Petición completada con éxito!
# Completado: Bruno  Armirail
# Empezando petición a: https://www.procyclingstats.com/rider/paul-double
# Petición completada con éxito!
# Completado: Paul  Double
# Empezando petición a: https://www.procyclingstats.com/rider/hugo-page
# Petición completada con éxito!
# Completado: Hugo  Page
# Empezando petición a: https://www.procyclingstats.com/rider/mathieu-burgaudeau
# Petición completada con éxito!
# Completado: Mathieu  Burgaudeau
# Empezando petición a: https://www.procyclingstats.com/rider/juan-pedro-lopez
# Petición completada con éxito!
# Completado: Juan Pedro  López
# Empezando petición a: https://www.procyclingstats.com/rider/quinn-simmons
# Petición completada con éxito!
# Completado: Quinn  Simmons
# Empezando petición a: https://www.procyclingstats.com/rider/jose-manuel-diaz-gallego
# Petición completada con éxito!
# Completado: José Manuel  Díaz
# Empezando petición a: https://www.procyclingstats.com/rider/xianjing-lyu
# Petición completada con éxito!
# Completado: Xianjing  Lyu
# Empezando petición a: https://www.procyclingstats.com/rider/brandon-smith-rivera-vargas
# Petición completada con éxito!
# Completado: Brandon Smith  Rivera
# Empezando petición a: https://www.procyclingstats.com/rider/eduard-prades
# Petición completada con éxito!
# Completado: Eduard  Prades
# Empezando petición a: https://www.procyclingstats.com/rider/rick-pluimers
# Petición completada con éxito!
# Completado: Rick  Pluimers
# Empezando petición a: https://www.procyclingstats.com/rider/mikkel-honore
# Petición completada con éxito!
# Completado: Mikkel Frølich  Honoré
# Empezando petición a: https://www.procyclingstats.com/rider/yannis-voisard
# Petición completada con éxito!
# Completado: Yannis  Voisard
# Empezando petición a: https://www.procyclingstats.com/rider/rafal-majka
# Petición completada con éxito!
# Completado: Rafał  Majka
# Empezando petición a: https://www.procyclingstats.com/rider/dries-van-gestel
# Petición completada con éxito!
# Completado: Dries Van Gestel
# Empezando petición a: https://www.procyclingstats.com/rider/stan-dewulf
# Petición completada con éxito!
# Completado: Stan  Dewulf
# Empezando petición a: https://www.procyclingstats.com/rider/ewen-costiou
# Petición completada con éxito!
# Completado: Ewen  Costiou
# Empezando petición a: https://www.procyclingstats.com/rider/brieuc-rolland
# Petición completada con éxito!
# Completado: Brieuc  Rolland
# Empezando petición a: https://www.procyclingstats.com/rider/marius-mayrhofer
# Petición completada con éxito!
# Completado: Marius  Mayrhofer
# Empezando petición a: https://www.procyclingstats.com/rider/thomas-gachignard
# Petición completada con éxito!
# Completado: Thomas  Gachignard
# Empezando petición a: https://www.procyclingstats.com/rider/riccardo-zoidl
# Petición completada con éxito!
# Completado: Riccardo  Zoidl
# Empezando petición a: https://www.procyclingstats.com/rider/junior-lecerf
# Petición completada con éxito!
# Completado: Junior  Lecerf
# Empezando petición a: https://www.procyclingstats.com/rider/rasmus-sojbergpedersen
# Petición completada con éxito!
# Completado: Rasmus Søjberg  Pedersen
# Empezando petición a: https://www.procyclingstats.com/rider/tobias-foss
# Petición completada con éxito!
# Completado: Tobias  Foss
# Empezando petición a: https://www.procyclingstats.com/rider/davide-formolo
# Petición completada con éxito!
# Completado: Davide  Formolo
# Empezando petición a: https://www.procyclingstats.com/rider/rui-oliveira
# Petición completada con éxito!
# Completado: Rui  Oliveira
# Empezando petición a: https://www.procyclingstats.com/rider/stefano-oldani
# Petición completada con éxito!
# Completado: Stefano  Oldani
# Empezando petición a: https://www.procyclingstats.com/rider/gregor-muhlberger
# Petición completada con éxito!
# Completado: Gregor  Mühlberger
# Empezando petición a: https://www.procyclingstats.com/rider/domenico-pozzovivo
# Petición completada con éxito!
# Completado: Domenico  Pozzovivo
# Empezando petición a: https://www.procyclingstats.com/rider/cian-uijtdebroeks
# Petición completada con éxito!
# Completado: Cian  Uijtdebroeks
# Empezando petición a: https://www.procyclingstats.com/rider/benjamin-thomas-2
# Petición completada con éxito!
# Completado: Benjamin  Thomas
# Empezando petición a: https://www.procyclingstats.com/rider/yevgeniy-fedorov
# Petición completada con éxito!
# Completado: Yevgeniy  Fedorov
# Empezando petición a: https://www.procyclingstats.com/rider/alex-kirsch
# Petición completada con éxito!
# Completado: Alex  Kirsch
# Empezando petición a: https://www.procyclingstats.com/rider/harm-vanhoucke
# Petición completada con éxito!
# Completado: Harm  Vanhoucke
# Empezando petición a: https://www.procyclingstats.com/rider/sam-welsford
# Petición completada con éxito!
# Completado: Sam  Welsford
# Empezando petición a: https://www.procyclingstats.com/rider/giovanni-lonardi
# Petición completada con éxito!
# Completado: Giovanni  Lonardi
# Empezando petición a: https://www.procyclingstats.com/rider/kevin-geniets
# Petición completada con éxito!
# Completado: Kevin  Geniets
# Empezando petición a: https://www.procyclingstats.com/rider/jakob-soderqvist
# Petición completada con éxito!
# Completado: Jakob  Söderqvist
# Empezando petición a: https://www.procyclingstats.com/rider/oded-kogut
# Petición completada con éxito!
# Completado: Oded  Kogut
# Empezando petición a: https://www.procyclingstats.com/rider/darren-rafferty
# Petición completada con éxito!
# Completado: Darren  Rafferty
# Empezando petición a: https://www.procyclingstats.com/rider/patrick-konrad
# Petición completada con éxito!
# Completado: Patrick  Konrad
# Empezando petición a: https://www.procyclingstats.com/rider/frederik-wandahl
# Petición completada con éxito!
# Completado: Frederik  Wandahl
# Empezando petición a: https://www.procyclingstats.com/rider/ivan-romeo
# Petición completada con éxito!
# Completado: Iván  Romeo
# Empezando petición a: https://www.procyclingstats.com/rider/jonathan-klever-caicedo
# Petición completada con éxito!
# Completado: Jonathan Klever  Caicedo
# Empezando petición a: https://www.procyclingstats.com/rider/jon-aberasturi
# Petición completada con éxito!
# Completado: Jon  Aberasturi
# Empezando petición a: https://www.procyclingstats.com/rider/franklin-archibold
# Petición completada con éxito!
# Completado: Franklin  Archibold
# Empezando petición a: https://www.procyclingstats.com/rider/nick-schultz
# Petición completada con éxito!
# Completado: Nick  Schultz
# Empezando petición a: https://www.procyclingstats.com/rider/pierre-barbier
# Petición completada con éxito!
# Completado: Pierre  Barbier
# Empezando petición a: https://www.procyclingstats.com/rider/timothy-dupont
# Petición completada con éxito!
# Completado: Timothy  Dupont
# Empezando petición a: https://www.procyclingstats.com/rider/jarne-van-de-paar
# Petición completada con éxito!
# Completado: Jarne Van de Paar
# Empezando petición a: https://www.procyclingstats.com/rider/andreas-leknessund
# Petición completada con éxito!
# Completado: Andreas  Leknessund
# Empezando petición a: https://www.procyclingstats.com/rider/tim-van-dijke
# Petición completada con éxito!
# Completado: Tim van Dijke
# Empezando petición a: https://www.procyclingstats.com/rider/bastien-tronchon
# Petición completada con éxito!
# Completado: Bastien  Tronchon
# Empezando petición a: https://www.procyclingstats.com/rider/filippo-magli2
# Petición completada con éxito!
# Completado: Filippo  Magli
# Empezando petición a: https://www.procyclingstats.com/rider/gianluca-brambilla
# Petición completada con éxito!
# Completado: Gianluca  Brambilla
# Empezando petición a: https://www.procyclingstats.com/rankings.php?date=2024-12-31&nation=&age=&zage=&page=smallerorequal&team=&offset=300&teamlevel=&filter=Filter&p=me&s=uci-individual
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/rider/carter-bettles
# Petición completada con éxito!
# Completado: Carter  Bettles
# Empezando petición a: https://www.procyclingstats.com/rider/giovanni-carboni
# Petición completada con éxito!
# Completado: Giovanni  Carboni
# Empezando petición a: https://www.procyclingstats.com/rider/soren-kragh-andersen
# Petición completada con éxito!
# Completado: Søren Kragh Andersen
# Empezando petición a: https://www.procyclingstats.com/rider/nelson-oliveira
# Petición completada con éxito!
# Completado: Nelson  Oliveira
# Empezando petición a: https://www.procyclingstats.com/rider/euro-kim
# Petición completada con éxito!
# Completado: Euro  Kim
# Empezando petición a: https://www.procyclingstats.com/rider/marton-dina
# Petición completada con éxito!
# Completado: Márton  Dina
# Empezando petición a: https://www.procyclingstats.com/rider/tord-gudmestad
# Petición completada con éxito!
# Completado: Tord  Gudmestad
# Empezando petición a: https://www.procyclingstats.com/rider/ryan-gibbons
# Petición completada con éxito!
# Completado: Ryan  Gibbons
# Empezando petición a: https://www.procyclingstats.com/rider/ryan-cavanagh
# Petición completada con éxito!
# Completado: Ryan  Cavanagh
# Empezando petición a: https://www.procyclingstats.com/rider/dillon-geary
# Petición completada con éxito!
# Completado: Dillon  Geary
# Empezando petición a: https://www.procyclingstats.com/rider/alexander-hajek
# Petición completada con éxito!
# Completado: Alexander  Hajek
# Empezando petición a: https://www.procyclingstats.com/rider/mattia-cattaneo
# Petición completada con éxito!
# Completado: Mattia  Cattaneo
# Empezando petición a: https://www.procyclingstats.com/rider/jannik-steimle
# Petición completada con éxito!
# Completado: Jannik  Steimle
# Empezando petición a: https://www.procyclingstats.com/rider/davide-cimolai
# Petición completada con éxito!
# Completado: Davide  Cimolai
# Empezando petición a: https://www.procyclingstats.com/rider/eric-antonio-fagundez
# Petición completada con éxito!
# Completado: Eric Antonio  Fagúndez
# Empezando petición a: https://www.procyclingstats.com/rider/sandy-dujardin
# Petición completada con éxito!
# Completado: Sandy  Dujardin
# Empezando petición a: https://www.procyclingstats.com/rider/rory-townsend
# Petición completada con éxito!
# Completado: Rory  Townsend
# Empezando petición a: https://www.procyclingstats.com/rider/jose-felix-parra
# Petición completada con éxito!
# Completado: José Félix  Parra
# Empezando petición a: https://www.procyclingstats.com/rider/red-walters
# Petición completada con éxito!
# Completado: Red  Walters
# Empezando petición a: https://www.procyclingstats.com/rider/jambaljamts-sainbayar
# Petición completada con éxito!
# Completado: Jambaljamts  Sainbayar
# Empezando petición a: https://www.procyclingstats.com/rider/tibor-del-grosso
# Petición completada con éxito!
# Completado: Tibor Del Grosso
# Empezando petición a: https://www.procyclingstats.com/rider/mark-donovan
# Petición completada con éxito!
# Completado: Mark  Donovan
# Empezando petición a: https://www.procyclingstats.com/rider/nairo-quintana
# Petición completada con éxito!
# Completado: Nairo  Quintana
# Empezando petición a: https://www.procyclingstats.com/rider/thomas-pesenti
# Petición completada con éxito!
# Completado: Thomas  Pesenti
# Empezando petición a: https://www.procyclingstats.com/rider/cristian-raileanu
# Petición completada con éxito!
# Completado: Cristian  Raileanu
# Empezando petición a: https://www.procyclingstats.com/rider/rui-costa
# Petición completada con éxito!
# Completado: Rui  Costa
# Empezando petición a: https://www.procyclingstats.com/rider/alessandro-pinarello
# Petición completada con éxito!
# Completado: Alessandro  Pinarello
# Empezando petición a: https://www.procyclingstats.com/rider/emils-liepins
# Petición completada con éxito!
# Completado: Emīls  Liepiņš
# Empezando petición a: https://www.procyclingstats.com/rider/metkel-eyob
# Petición completada con éxito!
# Completado: Metkel  Eyob
# Empezando petición a: https://www.procyclingstats.com/rider/julien-bernard
# Petición completada con éxito!
# Completado: Julien  Bernard
# Empezando petición a: https://www.procyclingstats.com/rider/jarno-widar
# Petición completada con éxito!
# Completado: Jarno  Widar
# Empezando petición a: https://www.procyclingstats.com/rider/mats-wenzel
# Petición completada con éxito!
# Completado: Mats  Wenzel
# Empezando petición a: https://www.procyclingstats.com/rider/alexis-renard
# Petición completada con éxito!
# Completado: Alexis  Renard
# Empezando petición a: https://www.procyclingstats.com/rider/jack-haig
# Petición completada con éxito!
# Completado: Jack  Haig
# Empezando petición a: https://www.procyclingstats.com/rider/carlos-verona
# Petición completada con éxito!
# Completado: Carlos  Verona
# Empezando petición a: https://www.procyclingstats.com/rider/leangel-linarez
# Petición completada con éxito!
# Completado: Leangel Rubén  Linarez
# Empezando petición a: https://www.procyclingstats.com/rider/raul-garcia-pierna
# Petición completada con éxito!
# Completado: Raúl  García Pierna
# Empezando petición a: https://www.procyclingstats.com/rider/lander-loockx
# Petición completada con éxito!
# Completado: Lander  Loockx
# Empezando petición a: https://www.procyclingstats.com/rider/martin-svrcek
# Petición completada con éxito!
# Completado: Martin  Svrček
# Empezando petición a: https://www.procyclingstats.com/rider/ethan-vernon
# Petición completada con éxito!
# Completado: Ethan  Vernon
# Empezando petición a: https://www.procyclingstats.com/rider/rodrigo-contreras
# Petición completada con éxito!
# Completado: Rodrigo  Contreras
# Empezando petición a: https://www.procyclingstats.com/rider/luca-van-boven
# Petición completada con éxito!
# Completado: Luca Van Boven
# Empezando petición a: https://www.procyclingstats.com/rider/martin-laas
# Petición completada con éxito!
# Completado: Martin  Laas
# Empezando petición a: https://www.procyclingstats.com/rider/manuele-tarozzi
# Petición completada con éxito!
# Completado: Manuele  Tarozzi
# Empezando petición a: https://www.procyclingstats.com/rider/brandon-downes
# Petición completada con éxito!
# Completado: Brandon  Downes
# Empezando petición a: https://www.procyclingstats.com/rider/huub-artz
# Petición completada con éxito!
# Completado: Huub  Artz
# Empezando petición a: https://www.procyclingstats.com/rider/nicolas-prodhomme
# Petición completada con éxito!
# Completado: Nicolas  Prodhomme
# ...
# Completado: Louis  Meintjes
# Empezando petición a: https://www.procyclingstats.com/rider/max-walker
# Petición completada con éxito!
# Completado: Max  Walker
# Empezando petición a: https://www.procyclingstats.com/rider/samuele-battistella
# Petición completada con éxito!
# Completado: Samuele  Battistella
# Empezando petición a: https://www.procyclingstats.com/rider/adne-van-engelen
# Petición completada con éxito!
# Completado: Adne van Engelen
# Empezando petición a: https://www.procyclingstats.com/rider/francisco-galvan
# Petición completada con éxito!
# Completado: Francisco  Galván
# Empezando petición a: https://www.procyclingstats.com/rider/alessandro-romele
# Petición completada con éxito!
# Completado: Alessandro  Romele
# Empezando petición a: https://www.procyclingstats.com/rider/louis-barre
# Petición completada con éxito!
# Completado: Louis  Barré
# Empezando petición a: https://www.procyclingstats.com/rider/jon-barrenetxea-golzarri
# Petición completada con éxito!
# Completado: Jon  Barrenetxea
# Empezando petición a: https://www.procyclingstats.com/rider/ben-zwiehoff
# Petición completada con éxito!
# Completado: Ben  Zwiehoff
# Empezando petición a: https://www.procyclingstats.com/rider/steff-cras
# Petición completada con éxito!
# Completado: Steff  Cras
# Empezando petición a: https://www.procyclingstats.com/rider/odd-christian-eiking
# Petición completada con éxito!
# Completado: Odd Christian  Eiking
# Empezando petición a: https://www.procyclingstats.com/rider/marco-frigo
# Petición completada con éxito!
# Completado: Marco  Frigo
# Empezando petición a: https://www.procyclingstats.com/rider/joan-bou
# Petición completada con éxito!
# Completado: Joan  Bou
# Empezando petición a: https://www.procyclingstats.com/rider/pablo-torres-arias
# Petición completada con éxito!
# Completado: Pablo  Torres
# Empezando petición a: https://www.procyclingstats.com/rider/hartthijs-de-vries
# Petición completada con éxito!
# Completado: Hartthijs de Vries
# Empezando petición a: https://www.procyclingstats.com/rider/itamar-einhorn
# Petición completada con éxito!
# Completado: Itamar  Einhorn
# Empezando petición a: https://www.procyclingstats.com/rankings.php?date=2024-12-31&nation=&age=&zage=&page=smallerorequal&team=&offset=400&teamlevel=&filter=Filter&p=me&s=uci-individual
# Petición completada con éxito!
# Empezando petición a: https://www.procyclingstats.com/rider/tom-donnenwirth
# Petición completada con éxito!
# Completado: Tom  Donnenwirth
# Empezando petición a: https://www.procyclingstats.com/rider/timo-kielich
# Petición completada con éxito!
# Completado: Timo  Kielich
# Empezando petición a: https://www.procyclingstats.com/rider/sente-sentjens
# Petición completada con éxito!
# Completado: Sente  Sentjens
# Empezando petición a: https://www.procyclingstats.com/rider/norbert-banaszek
# Petición completada con éxito!
# Completado: Norbert  Banaszek
# Empezando petición a: https://www.procyclingstats.com/rider/mario-aparicio-munoz
# Petición completada con éxito!
# Completado: Mario  Aparicio
# Empezando petición a: https://www.procyclingstats.com/rider/yuma-koishi
# Petición completada con éxito!
# Completado: Yuma  Koishi
# Empezando petición a: https://www.procyclingstats.com/rider/christopher-rougier-lagane
# Petición completada con éxito!
# Completado: Christopher  Rougier-Lagane
# Empezando petición a: https://www.procyclingstats.com/rider/patryk-stosz
# Petición completada con éxito!
# Completado: Patryk  Stosz
# Empezando petición a: https://www.procyclingstats.com/rider/john-degenkolb
# Petición completada con éxito!
# Completado: John  Degenkolb
# Empezando petición a: https://www.procyclingstats.com/rider/emanuel-buchmann
# Petición completada con éxito!
# Completado: Emanuel  Buchmann
# Empezando petición a: https://www.procyclingstats.com/rider/joel-nicolau
# Petición completada con éxito!
# Completado: Joel  Nicolau
# Empezando petición a: https://www.procyclingstats.com/rider/krists-neilands
# Petición completada con éxito!
# Completado: Krists  Neilands
# Empezando petición a: https://www.procyclingstats.com/rider/matteo-sobrero
# Petición completada con éxito!
# Completado: Matteo  Sobrero
# Empezando petición a: https://www.procyclingstats.com/rider/alessandro-tonelli
# Petición completada con éxito!
# Completado: Alessandro  Tonelli
# Empezando petición a: https://www.procyclingstats.com/rider/victor-langellotti
# Petición completada con éxito!
# Completado: Victor  Langellotti
# Empezando petición a: https://www.procyclingstats.com/rider/david-de-la-cruz
# Petición completada con éxito!
# Completado: David de la Cruz
# Empezando petición a: https://www.procyclingstats.com/rider/dmitriy-bocharov
# Petición completada con éxito!
# Completado: Dmitriy  Bocharov
# Empezando petición a: https://www.procyclingstats.com/rider/davide-ballerini
# Petición completada con éxito!
# Completado: Davide  Ballerini
# Empezando petición a: https://www.procyclingstats.com/rider/ilkhan-dostiyev
# Petición completada con éxito!
# Completado: Ilkhan  Dostiyev
# Empezando petición a: https://www.procyclingstats.com/rider/matteo-malucelli
# Petición completada con éxito!
# Completado: Matteo  Malucelli
# Empezando petición a: https://www.procyclingstats.com/rider/karl-patrick-lauk
# Petición completada con éxito!
# Completado: Karl Patrick  Lauk
# Empezando petición a: https://www.procyclingstats.com/rider/koen-bouwman
# Petición completada con éxito!
# Completado: Koen  Bouwman
# Empezando petición a: https://www.procyclingstats.com/rider/simon-dalby
# Petición completada con éxito!
# Completado: Simon  Dalby
# Empezando petición a: https://www.procyclingstats.com/rider/tegsh-bayar-batsaikhan
# Petición completada con éxito!
# Completado: Tegsh-bayar  Batsaikhan
# Empezando petición a: https://www.procyclingstats.com/rider/walter-vargas
# Petición completada con éxito!
# Completado: Walter  Vargas
# Empezando petición a: https://www.procyclingstats.com/rider/harold-martin-lopez
# Petición completada con éxito!
# Completado: Harold Martín  López
# Empezando petición a: https://www.procyclingstats.com/rider/emmanuel-morin
# Petición completada con éxito!
# Completado: Emmanuel  Morin
# Empezando petición a: https://www.procyclingstats.com/rider/arne-marit
# Petición completada con éxito!
# Completado: Arne  Marit
# Empezando petición a: https://www.procyclingstats.com/rider/anthon-charmig
# Petición completada con éxito!
# Completado: Anthon  Charmig
# Empezando petición a: https://www.procyclingstats.com/rider/anatoliy-budyak
# Petición completada con éxito!
# Completado: Anatoliy  Budyak
# Empezando petición a: https://www.procyclingstats.com/rider/andreas-miltiadis
# Petición completada con éxito!
# Completado: Andreas  Miltiadis
# Empezando petición a: https://www.procyclingstats.com/rider/emile-van-niekerk
# Petición completada con éxito!
# Completado: Emile van Niekerk
# Empezando petición a: https://www.procyclingstats.com/rider/ben-turner
# Petición completada con éxito!
# Completado: Ben  Turner
# Empezando petición a: https://www.procyclingstats.com/rider/logan-currie
# Petición completada con éxito!
# Completado: Logan  Currie
# Empezando petición a: https://www.procyclingstats.com/rider/maikel-zijlaard
# Petición completada con éxito!
# Completado: Maikel  Zijlaard
# Empezando petición a: https://www.procyclingstats.com/rider/simon-geschke
# Petición completada con éxito!
# Completado: Simon  Geschke
# Empezando petición a: https://www.procyclingstats.com/rider/chris-hamilton
# Petición completada con éxito!
# Completado: Chris  Hamilton
# Empezando petición a: https://www.procyclingstats.com/rider/mattia-bais
# Petición completada con éxito!
# Completado: Mattia  Bais
# Empezando petición a: https://www.procyclingstats.com/rider/johan-esteban-chaves
# Petición completada con éxito!
# Completado: Esteban  Chaves
# Empezando petición a: https://www.procyclingstats.com/rider/jakub-mareczko
# Petición completada con éxito!
# Completado: Jakub  Mareczko
# Empezando petición a: https://www.procyclingstats.com/rider/damiano-caruso
# Petición completada con éxito!
# Completado: Damiano  Caruso
# Empezando petición a: https://www.procyclingstats.com/rider/miguel-heidemann
# Petición completada con éxito!
# Completado: Miguel  Heidemann
# Empezando petición a: https://www.procyclingstats.com/rider/el-houcaine-sabbahi
# Petición completada con éxito!
# Completado: El Houcaine  Sabbahi
# Empezando petición a: https://www.procyclingstats.com/rider/unai-iribar-jauregi
# Petición completada con éxito!
# Completado: Unai  Iribar
# Empezando petición a: https://www.procyclingstats.com/rider/ceriel-desal
# Petición completada con éxito!
# Completado: Ceriel  Desal
# Empezando petición a: https://www.procyclingstats.com/rider/jake-stewart
# Petición completada con éxito!
# Completado: Jake  Stewart
# Empezando petición a: https://www.procyclingstats.com/rider/yacine-hamza
# Petición completada con éxito!
# Completado: Yacine  Hamza
# Empezando petición a: https://www.procyclingstats.com/rider/moise-mugisha
# Petición completada con éxito!
# Completado: Moise  Mugisha
# Empezando petición a: https://www.procyclingstats.com/rider/nikiforos-arvanitou
# Petición completada con éxito!
# Completado: Nikiforos  Arvanitou
# Empezando petición a: https://www.procyclingstats.com/rider/muhammad-nur-aiman-bin-rosli
# Petición completada con éxito!
# Completado: Muhammad Nur Aiman Bin  Rosli
# Empezando petición a: https://www.procyclingstats.com/rider/florian-samuel-kajamini
# Petición completada con éxito!
# Completado: Florian Samuel  Kajamini
# Empezando petición a: https://www.procyclingstats.com/rider/sergio-geovani-chumil-gonzalez
# Petición completada con éxito!
# Completado: Sergio Geovani  Chumil
# Empezando petición a: https://www.procyclingstats.com/rider/sam-oomen
# Petición completada con éxito!
# Completado: Sam  Oomen
# Empezando petición a: https://www.procyclingstats.com/rider/gianmarco-garofoli
# Petición completada con éxito!
# Completado: Gianmarco  Garofoli
# Empezando petición a: https://www.procyclingstats.com/rider/andrea-bagioli
# Petición completada con éxito!
# Completado: Andrea  Bagioli
# Empezando petición a: https://www.procyclingstats.com/rider/nicolas-vinokurov
# Petición completada con éxito!
# Completado: Nicolas  Vinokurov
# Empezando petición a: https://www.procyclingstats.com/rider/tyler-stites
# Petición completada con éxito!
# Completado: Tyler  Stites
# Empezando petición a: https://www.procyclingstats.com/rider/mirco-maestri
# Petición completada con éxito!
# Completado: Mirco  Maestri
# Empezando petición a: https://www.procyclingstats.com/rider/nicola-conci
# Petición completada con éxito!
# Completado: Nicola  Conci
# Empezando petición a: https://www.procyclingstats.com/rider/thibaud-gruel
# Petición completada con éxito!
# Completado: Thibaud  Gruel
# Empezando petición a: https://www.procyclingstats.com/rider/gleb-brussenskiy
# Petición completada con éxito!
# Completado: Gleb  Brussenskiy
# Empezando petición a: https://www.procyclingstats.com/rider/igor-arrieta-lizarraga
# Petición completada con éxito!
# Completado: Igor  Arrieta
# Empezando petición a: https://www.procyclingstats.com/rider/mick-van-dijke
# Petición completada con éxito!
# Completado: Mick van Dijke
# Empezando petición a: https://www.procyclingstats.com/rider/jackson-medway
# Petición completada con éxito!
# Completado: Jackson  Medway
# Empezando petición a: https://www.procyclingstats.com/rider/thanakhan-chaiyasombat
# Petición completada con éxito!
# Completado: Thanakhan  Chaiyasombat
# Empezando petición a: https://www.procyclingstats.com/rider/ivan-ramiro-sosa
# Petición completada con éxito!
# Completado: Iván Ramiro  Sosa
# Empezando petición a: https://www.procyclingstats.com/rider/dawit-yemane
# Petición completada con éxito!
# Completado: Dawit  Yemane
# Empezando petición a: https://www.procyclingstats.com/rider/aime-de-gendt
# Petición completada con éxito!
# Completado: Aimé De Gendt
# Empezando petición a: https://www.procyclingstats.com/rider/pascal-eenkhoorn
# Petición completada con éxito!
# Completado: Pascal  Eenkhoorn
# Empezando petición a: https://www.procyclingstats.com/rider/filippo-fiorelli
# Petición completada con éxito!
# Completado: Filippo  Fiorelli
# Empezando petición a: https://www.procyclingstats.com/rider/abdulla-jasim-al-ali
# Petición completada con éxito!
# Completado: Abdulla  Jasim Al-Ali
# Empezando petición a: https://www.procyclingstats.com/rider/damien-touze
# Petición completada con éxito!
# Completado: Damien  Touzé
# Empezando petición a: https://www.procyclingstats.com/rider/mikel-bizkarra
# Petición completada con éxito!
# Completado: Mikel  Bizkarra
# Empezando petición a: https://www.procyclingstats.com/rider/ivan-garcia-cortina
# Petición completada con éxito!
# Completado: Iván  García Cortina
# Empezando petición a: https://www.procyclingstats.com/rider/kamiel-bonneu
# Petición completada con éxito!
# Completado: Kamiel  Bonneu
# Empezando petición a: https://www.procyclingstats.com/rider/milkias-maekele
# Petición completada con éxito!
# Completado: Milkias  Maekele
# Empezando petición a: https://www.procyclingstats.com/rider/enrico-zanoncello
# Petición completada con éxito!
# Completado: Enrico  Zanoncello
# Empezando petición a: https://www.procyclingstats.com/rider/axel-mariault
# Petición completada con éxito!
# Completado: Axel  Mariault
# Empezando petición a: https://www.procyclingstats.com/rider/xabier-berasategi-garmendia
# Petición completada con éxito!
# Completado: Xabier  Berasategi
# Empezando petición a: https://www.procyclingstats.com/rider/lars-boven
# Petición completada con éxito!
# Completado: Lars  Boven
# Empezando petición a: https://www.procyclingstats.com/rider/marco-tizza
# Petición completada con éxito!
# Completado: Marco  Tizza
# Empezando petición a: https://www.procyclingstats.com/rider/morne-van-niekerk
# Petición completada con éxito!
# Completado: Morné Van Niekerk
# Empezando petición a: https://www.procyclingstats.com/rider/alessandro-covi
# Petición completada con éxito!
# Completado: Alessandro  Covi
# Empezando petición a: https://www.procyclingstats.com/rider/matevz-govekar
# Petición completada con éxito!
# Completado: Matevž  Govekar
# Empezando petición a: https://www.procyclingstats.com/rider/ibrahim-essabahy
# Petición completada con éxito!
# Completado: Ibrahim  Essabahy
# Empezando petición a: https://www.procyclingstats.com/rider/joris-delbove
# Petición completada con éxito!
# Completado: Joris  Delbove
# Empezando petición a: https://www.procyclingstats.com/rider/kelland-brien
# Petición completada con éxito!
# Completado: Kelland  O'Brien
# Empezando petición a: https://www.procyclingstats.com/rider/wessel-mouris
# Petición completada con éxito!
# Completado: Wessel  Mouris
# Empezando petición a: https://www.procyclingstats.com/rider/afonso-eulalio
# Petición completada con éxito!
# Completado: Afonso  Eulálio
# Empezando petición a: https://www.procyclingstats.com/rider/fabian-weiss
# Petición completada con éxito!
# Completado: Fabian  Weiss
# Empezando petición a: https://www.procyclingstats.com/rider/luca-vergallito
# Petición completada con éxito!
# Completado: Luca  Vergallito
# Empezando petición a: https://www.procyclingstats.com/rider/negasi-abreha
# Petición completada con éxito!
# Completado: Negasi Haylu  Abreha
# Empezando petición a: https://www.procyclingstats.com/rider/lawrence-warbasse
# Petición completada con éxito!
# Completado: Larry  Warbasse
# Empezando petición a: https://www.procyclingstats.com/rider/jakob-fuglsang
# Petición completada con éxito!
# Completado: Jakob  Fuglsang
# Empezando petición a: https://www.procyclingstats.com/rider/callum-scotson
# Petición completada con éxito!
# Completado: Callum  Scotson
# Empezando petición a: https://www.procyclingstats.com/rider/daniel-bonilla
# Petición completada con éxito!
# Completado: Daniel Andres  Bonilla
# Empezando petición a: https://www.procyclingstats.com/rider/simon-guglielmi
# Petición completada con éxito!
# Completado: Simon  Guglielmi
# Empezando petición a: https://www.procyclingstats.com/rider/ivo-emanuel-alves
# Petición completada con éxito!
# Completado: Ivo  Oliveira
# Empezando petición a: https://www.procyclingstats.com/rider/tao-geoghegan-hart
# Petición completada con éxito!
# Completado: Tao  Geoghegan Hart
# Empezando petición a: https://www.procyclingstats.com/rider/axel-huens
# Petición completada con éxito!
# Completado: Axel  Huens
